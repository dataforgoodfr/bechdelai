# %% [markdown]
# # Analyse subtitles of Harry Potter 4
#
# In this notebook we'll go throught Harry Potter 4 subtitles to see if we can find some entities in the text and if we can map it with characters.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

from bechdelai.nlp.process_srt import load_srt
from bechdelai.data.tmdb import get_movie_cast_from_id
from bechdelai.nlp.analyse_srt import extract_person_references_in_srt
from bechdelai.nlp.entities import match_entities_with_cast

# %%
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Load data

# %% [markdown]
# Srt file

# %%
fpath = "../../../data/srt/harry_potter_4.srt"
srt_list = load_srt(fpath)

# %%
for srt in srt_list[:2]:
    print(srt)
# Out:
# 1
# 00:01:46,125 --> 00:01:48,543
# Bloody kids.
#
# 2
# 00:02:35,007 --> 00:02:38,676
# How fastidious you've become,
# Wormtail.

# %% [markdown]
# TMDB meta data

# %%
tmdb_id = "674"
cast = get_movie_cast_from_id(tmdb_id)["cast"]

# %%
cast_df = pd.DataFrame(cast)
cast_df.head()
# Out:
#    adult  gender     id known_for_department              name  \
# 0  False       2  10980               Acting  Daniel Radcliffe
# 1  False       2  10989               Acting      Rupert Grint
# 2  False       1  10990               Acting       Emma Watson
# 3  False       2   1923               Acting   Robbie Coltrane
# 4  False       2   5469               Acting     Ralph Fiennes
#
#       original_name  popularity                      profile_path  cast_id  \
# 0  Daniel Radcliffe      60.579  /iPg0J9UzAlPj1fLEJNllpW9IhGe.jpg        1
# 1      Rupert Grint      34.387  /q2KZZ0ltTEl7Sf8volNFV1JDEP4.jpg        2
# 2       Emma Watson      64.354  /tvPPRGzAzdQFhlKzLbMO1EpuTJI.jpg        3
# 3   Robbie Coltrane      21.872  /jOHs3xvlwRiiG2CLtso5zzmGCXg.jpg        7
# 4     Ralph Fiennes      66.925  /tJr9GcmGNHhLVVEH3i7QYbj6hBi.jpg        4
#
#           character                 credit_id  order
# 0      Harry Potter  52fe4268c3a36847f801c21d      0
# 1       Ron Weasley  52fe4268c3a36847f801c221      1
# 2  Hermione Granger  52fe4268c3a36847f801c225      2
# 3     Rubeus Hagrid  52fe4268c3a36847f801c235      3
# 4    Lord Voldemort  52fe4268c3a36847f801c229      4

# %% [markdown]
# ## Get entities and nouns

# %%
# %%time
results = extract_person_references_in_srt(srt_list, 100)
# Out:
# Wall time: 20.9 s

# %%
results.sample(20)
# Out:
#      srt_id                                               text  start_sec  \
# 44       31                                            Arthur!        270
# 81       67            - Excellent, excellent.\n- Ginny, look!        420
# 16        8  It cannot be done without him.\nAnd it will be...        178
# 79       64                             See you later, Cedric.        401
# 73       61            Parting of the ways, I think, old chap.        395
# 89       76                             Well, put it this way:        460
# 24       13       Nagini tells me\nthe old Muggle caretaker...        206
# 61       42                           - Shall we?\n- Oh, yeah.        307
# 28       15  Step aside, Wormtail,\nso I can give our guest...        213
# 93       79         Father and I are in\nthe minister's box...        466
# 113      89                         Ireland! Ireland! Ireland!        516
# 36       21         - When did you get here?\n- Just now. You?        236
# 13        7                         No! The boy is everything!        175
# 118      93                                  Krum! Krum! Krum!        540
# 125      99        ...to welcome\neach and every one of you...        568
# 111      89                         Ireland! Ireland! Ireland!        516
# 108      87                      It's the Irish! There's Troy!        506
# 51       34  This is Amos Diggory, everyone.\nWorks with me...        278
# 37       21         - When did you get here?\n- Just now. You?        236
# 84       71  - Yeah, get out of the kitchen, Ron!\n- Feet o...        429
#
#      end_sec       ent  start_idx  end_idx ent_type   gender
# 44       271  Arthur !          0        2      PER  unknown
# 81       422     Ginny          6        7      PER  unknown
# 16       182       him          6        7     PRON      man
# 79       402       you          1        2     PRON  unknown
# 73       397         I          5        6     PRON  unknown
# 89       461        it          3        4     PRON  unknown
# 24       209    Nagini          0        1      PER  unknown
# 61       309        we          2        3     PRON  unknown
# 28       219  Wormtail          3        4     MISC  unknown
# 93       469         I          2        3     PRON  unknown
# 113      519   Ireland          4        5    PROPN  unknown
# 36       239       you          3        4     PRON  unknown
# 13       178       boy          3        4     NOUN  unknown
# 118      543      Krum          2        3    PROPN  unknown
# 125      572       you          8        9     PRON  unknown
# 111      519   Ireland          0        1    PROPN  unknown
# 108      508     There          5        6     PRON  unknown
# 51       284  Ministry         12       13    PROPN  unknown
# 37       239       You         11       12     PRON  unknown
# 84       431     Ron !          9       11      PER  unknown

# %%
results_with_cast = match_entities_with_cast(results, cast_df)

# %%
results_with_cast.sample(20)
# Out:
#      srt_id                                               text  start_sec  \
# 88       75                    Blimey, Dad. How far up are we?        456
# 125      99        ...to welcome\neach and every one of you...        568
# 21       10     - I will not disappoint you, my Lord.\n- Good.        185
# 117      93                                  Krum! Krum! Krum!        540
# 89       76                             Well, put it this way:        460
# 69       49        - Ready! After three. One, two...\n- Harry!        324
# 67       48                                  What's a Portkey?        323
# 86       74       Get your Quidditch World Cup\nprograms here!        453
# 11        6   ...perhaps if we were to do it\nwithout the boy.        172
# 119      93                                  Krum! Krum! Krum!        540
# 8         4                 Oh, no. No, no, my Lord Voldemort.        168
# 95       79         Father and I are in\nthe minister's box...        466
# 15        8  It cannot be done without him.\nAnd it will be...        178
# 68       48                                  What's a Portkey?        323
# 4         3  Could it be that the task of nursing me\nhas b...        163
# 78       64                             See you later, Cedric.        401
# 105      87                      It's the Irish! There's Troy!        506
# 13        7                         No! The boy is everything!        175
# 103      85  Come on up. Take your seats. I told you\nthese...        497
# 109      88                        - And Mullet!\n- And Moran!        508
#
#      end_sec                  ent  start_idx  end_idx ent_type   gender  \
# 88       459                   we          8        9     PRON  unknown
# 125      572                  you          8        9     PRON  unknown
# 21       189                  you          5        6     PRON  unknown
# 117      543                 Krum          0        1    PROPN      man
# 89       461                   it          3        4     PRON  unknown
# 69       328              Harry !         11       13      PER      man
# 67       324                 What          0        1     PRON  unknown
# 86       456  Quidditch World Cup          2        5     MISC  unknown
# 11       175                   it          7        8     PRON  unknown
# 119      543                 Krum          4        5    PROPN      man
# 8        171                 Lord          9       10    PROPN      man
# 95       469                  box          8        9    PROPN  unknown
# 15       182                   It          0        1     PRON  unknown
# 68       324              Portkey          3        4    PROPN  unknown
# 4        168                   it          1        2     PRON  unknown
# 78       402               Cedric          4        5      PER      man
# 105      508                Irish          3        4     MISC  unknown
# 13       178                  boy          3        4     NOUN  unknown
# 103      502                    I          8        9     PRON  unknown
# 109      510                Moran          6        7      PER  unknown
#
#     character_found
# 88
# 125
# 21
# 117     Viktor Krum
# 89
# 69     Harry Potter
# 67
# 86
# 11
# 119     Viktor Krum
# 8    Lord Voldemort
# 95
# 15
# 68
# 4
# 78   Cedric Diggory
# 105
# 13
# 103
# 109

# %% [markdown]
# TODO :
# - Match with character name OK
# - Handle idx problem OK
# - remove other notebooks OK
# - remove subtitles.py OK
# - remove unused function
# - get path syn dict from path
# - documentaiton
# - Test ?
