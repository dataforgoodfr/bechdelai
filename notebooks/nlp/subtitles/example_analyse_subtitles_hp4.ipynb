# %% [markdown]
# # Analyse subtitles of Harry Potter 4
#
# In this notebook we'll go throught Harry Potter 4 subtitles to see if we can find some entities in the text and if we can map it with characters.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

from bechdelai.nlp.process_srt import load_srt
from bechdelai.data.tmdb import get_movie_cast_from_id
from bechdelai.nlp.analyse_srt import extract_person_references_in_srt
# Out:
# 2023-01-18 19:51:25,597 loading file C:\Users\natha\.flair\models\ner-english\4f4cdab26f24cb98b732b389e6cebc646c36f54cfd6e0b7d3b90b25656e4262f.8baa8ae8795f4df80b28e7f7b61d788ecbb057d1dc85aacb316f1bd02837a4a4
# 2023-01-18 19:51:27,354 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>

# %%
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Load data

# %% [markdown]
# Srt file

# %%
fpath = "../../../data/srt/harry_potter_4.srt"
srt_list = load_srt(fpath)

# %%
for srt in srt_list[:2]:
    print(srt)
# Out:
# 1
# 00:01:46,125 --> 00:01:48,543
# Bloody kids.
#
# 2
# 00:02:35,007 --> 00:02:38,676
# How fastidious you've become,
# Wormtail.

# %% [markdown]
# TMDB meta data

# %%
tmdb_id = "674"
cast = get_movie_cast_from_id(tmdb_id)["cast"]

# %%
cast_df = pd.DataFrame(cast)
cast_df.head()
# Out:
#    adult  gender     id known_for_department              name  \
# 0  False       2  10980               Acting  Daniel Radcliffe
# 1  False       2  10989               Acting      Rupert Grint
# 2  False       1  10990               Acting       Emma Watson
# 3  False       2   1923               Acting   Robbie Coltrane
# 4  False       2   5469               Acting     Ralph Fiennes
#
#       original_name  popularity                      profile_path  cast_id  \
# 0  Daniel Radcliffe      44.237  /iPg0J9UzAlPj1fLEJNllpW9IhGe.jpg        1
# 1      Rupert Grint      28.539  /q2KZZ0ltTEl7Sf8volNFV1JDEP4.jpg        2
# 2       Emma Watson      51.889  /tvPPRGzAzdQFhlKzLbMO1EpuTJI.jpg        3
# 3   Robbie Coltrane      17.409  /jOHs3xvlwRiiG2CLtso5zzmGCXg.jpg        7
# 4     Ralph Fiennes      88.056  /tJr9GcmGNHhLVVEH3i7QYbj6hBi.jpg        4
#
#           character                 credit_id  order
# 0      Harry Potter  52fe4268c3a36847f801c21d      0
# 1       Ron Weasley  52fe4268c3a36847f801c221      1
# 2  Hermione Granger  52fe4268c3a36847f801c225      2
# 3     Rubeus Hagrid  52fe4268c3a36847f801c235      3
# 4    Lord Voldemort  52fe4268c3a36847f801c229      4

# %% [markdown]
# ## Get entities and nouns

# %%
# %%time
results = extract_person_references_in_srt(srt_list, 50)
# Out:
# Wall time: 15.9 s

# %%
results
# Out:
#     srt_id                                               text  start_sec  \
# 0        1           How fastidious you've become,\nWormtail.        155
# 1        1           How fastidious you've become,\nWormtail.        155
# 2        1           How fastidious you've become,\nWormtail.        155
# 3        2  As I recall, you once called\nthe nearest gutt...        158
# 4        2  As I recall, you once called\nthe nearest gutt...        158
# 5        3  Could it be that the task of nursing me\nhas b...        163
# 6        3  Could it be that the task of nursing me\nhas b...        163
# 7        3  Could it be that the task of nursing me\nhas b...        163
# 8        4                 Oh, no. No, no, my Lord Voldemort.        168
# 9        4                 Oh, no. No, no, my Lord Voldemort.        168
# 10       5                                    I only meant...        171
# 11       6   ...perhaps if we were to do it\nwithout the boy.        172
# 12       6   ...perhaps if we were to do it\nwithout the boy.        172
# 13       6   ...perhaps if we were to do it\nwithout the boy.        172
# 14       7                         No! The boy is everything!        175
# 15       7                         No! The boy is everything!        175
# 16       8  It cannot be done without him.\nAnd it will be...        178
# 17       8  It cannot be done without him.\nAnd it will be...        178
# 18       8  It cannot be done without him.\nAnd it will be...        178
# 19       9                                 Exactly as I said.        182
# 20      10     - I will not disappoint you, my Lord.\n- Good.        185
# 21      10     - I will not disappoint you, my Lord.\n- Good.        185
# 22      10     - I will not disappoint you, my Lord.\n- Good.        185
# 23      10     - I will not disappoint you, my Lord.\n- Good.        185
# 24      12                                  Send them a sign.        192
# 25      13       Nagini tells me\nthe old Muggle caretaker...        206
# 26      13       Nagini tells me\nthe old Muggle caretaker...        206
# 27      13       Nagini tells me\nthe old Muggle caretaker...        206
# 28      13       Nagini tells me\nthe old Muggle caretaker...        206
# 29      13       Nagini tells me\nthe old Muggle caretaker...        206
# 30      13       Nagini tells me\nthe old Muggle caretaker...        206
# 31      15  Step aside, Wormtail,\nso I can give our guest...        213
# 32      15  Step aside, Wormtail,\nso I can give our guest...        213
# 33      15  Step aside, Wormtail,\nso I can give our guest...        213
# 34      15  Step aside, Wormtail,\nso I can give our guest...        213
# 35      16                                     Avada Kedavra!        219
# 36      16                                     Avada Kedavra!        219
# 37      17                                             Harry.        226
# 38      17                                             Harry.        226
# 39      18                                             Harry!        228
# 40      19                                 Are you all right?        231
# 41      20                               Hermione. Bad dream.        233
# 42      21         - When did you get here?\n- Just now. You?        236
# 43      21         - When did you get here?\n- Just now. You?        236
# 44      23                          Wake up! Wake up, Ronald!        241
# 45      27  Come on, Ron!\nYour mother says breakfast's re...        249
# 46      28  - Ron, where are we actually going?\n- Don't k...        259
# 47      28  - Ron, where are we actually going?\n- Don't k...        259
# 48      28  - Ron, where are we actually going?\n- Don't k...        259
# 49      29  - Hey, Dad. Where are we going?\n- Haven't the...        262
# 50      29  - Hey, Dad. Where are we going?\n- Haven't the...        262
# 51      29  - Hey, Dad. Where are we going?\n- Haven't the...        262
# 52      31                                            Arthur!        270
# 53      32                              It's about time, son.        272
# 54      33  Sorry, Amos. Some of us\nhad a bit of a sleepy...        274
# 55      33  Sorry, Amos. Some of us\nhad a bit of a sleepy...        274
# 56      33  Sorry, Amos. Some of us\nhad a bit of a sleepy...        274
# 57      34  This is Amos Diggory, everyone.\nWorks with me...        278
# 58      34  This is Amos Diggory, everyone.\nWorks with me...        278
# 59      34  This is Amos Diggory, everyone.\nWorks with me...        278
# 60      34  This is Amos Diggory, everyone.\nWorks with me...        278
# 61      34  This is Amos Diggory, everyone.\nWorks with me...        278
# 62      35  And this strapping young lad\nmust be Cedric, ...        284
# 63      35  And this strapping young lad\nmust be Cedric, ...        284
# 64      35  And this strapping young lad\nmust be Cedric, ...        284
# 65      35  And this strapping young lad\nmust be Cedric, ...        284
# 66      38         Merlin's beard!\nYou must be Harry Potter.        292
# 67      38         Merlin's beard!\nYou must be Harry Potter.        292
# 68      38         Merlin's beard!\nYou must be Harry Potter.        292
# 69      38         Merlin's beard!\nYou must be Harry Potter.        292
# 70      38         Merlin's beard!\nYou must be Harry Potter.        292
# 71      38         Merlin's beard!\nYou must be Harry Potter.        292
# 72      40                     Pleasure to meet you too, sir.        298
# 73      41                         Yes, it's just over there.        302
# 74      42                           - Shall we?\n- Oh, yeah.        307
# 75      43                          We don't want to be late.        309
# 76      44  Come on. Nearly there now.\nGet yourself into ...        311
# 77      44  Come on. Nearly there now.\nGet yourself into ...        311
# 78      45  Why are they all standing around\nthat manky o...        316
# 79      46  - That isn't just any manky old boot.\n- It's ...        318
# 80      46  - That isn't just any manky old boot.\n- It's ...        318
# 81      46  - That isn't just any manky old boot.\n- It's ...        318
# 82      48                                  What's a Portkey?        323
# 83      48                                  What's a Portkey?        323
# 84      49        - Ready! After three. One, two...\n- Harry!        324
# 85      49        - Ready! After three. One, two...\n- Harry!        324
#
#     end_sec            ent  start_idx  end_idx ent_type   gender
# 0       158       Wormtail          6        7     MISC  unknown
# 1       158            you          3        4     PRON  unknown
# 2       158       Wormtail          8        9    PROPN  unknown
# 3       163              I          2        3     PRON  unknown
# 4       163            you          5        6     PRON  unknown
# 5       168             it          2        3     PRON  unknown
# 6       168             me          9       10     PRON  unknown
# 7       168            you         15       16     PRON  unknown
# 8       171      Voldemort         10       11      PER  unknown
# 9       171      Voldemort         11       12    PROPN  unknown
# 10      172              I          1        2     PRON  unknown
# 11      175             we          4        5     PRON  unknown
# 12      175             it          8        9     PRON  unknown
# 13      175            boy         12       13     NOUN  unknown
# 14      178            boy          4        5     NOUN  unknown
# 15      178     everything          6        7     PRON  unknown
# 16      182             It          1        2     PRON  unknown
# 17      182            him          7        8     PRON      man
# 18      182             it         11       12     PRON  unknown
# 19      184              I          3        4     PRON  unknown
# 20      189           Good         11       12      PER  unknown
# 21      189              I          2        3     PRON  unknown
# 22      189            you          6        7     PRON  unknown
# 23      189           Lord          9       10    PROPN  unknown
# 24      194           them          2        3     PRON  unknown
# 25      209         Nagini          0        1      PER  unknown
# 26      209         Muggle          5        6     MISC  unknown
# 27      209         Nagini          1        2    PROPN  unknown
# 28      209             me          3        4     PRON  unknown
# 29      209         Muggle          7        8    PROPN  unknown
# 30      209      caretaker          8        9     NOUN  unknown
# 31      219       Wormtail          3        4     MISC  unknown
# 32      219       Wormtail          4        5    PROPN  unknown
# 33      219              I          8        9     PRON  unknown
# 34      219          guest         12       13     NOUN  unknown
# 35      221  Avada Kedavra          0        2      PER  unknown
# 36      221        Kedavra          2        3    PROPN  unknown
# 37      227          Harry          0        1      PER  unknown
# 38      227          Harry          1        2    PROPN  unknown
# 39      230        Harry !          0        2      PER  unknown
# 40      233            you          2        3     PRON  unknown
# 41      236       Hermione          0        1      PER  unknown
# 42      239            you          4        5     PRON  unknown
# 43      239            You         13       14     PRON  unknown
# 44      243       Ronald !          6        8      PER  unknown
# 45      252          Ron !          3        5      PER  unknown
# 46      262            Ron          1        2      PER  unknown
# 47      262            Ron          2        3    PROPN  unknown
# 48      262             we          6        7     PRON  unknown
# 49      265            Dad          3        4      PER  unknown
# 50      265            Dad          4        5    PROPN  unknown
# 51      265             we          8        9     PRON  unknown
# 52      271       Arthur !          0        2      PER  unknown
# 53      274             It          1        2     PRON  unknown
# 54      278           Amos          2        3      PER  unknown
# 55      278           Amos          3        4    PROPN  unknown
# 56      278             us          7        8     PRON  unknown
# 57      284   Amos Diggory          2        4      PER  unknown
# 58      284        Diggory          4        5    PROPN  unknown
# 59      284       everyone          6        7     PRON  unknown
# 60      284             me         11       12     PRON  unknown
# 61      284       Ministry         14       15    PROPN  unknown
# 62      287         Cedric          7        8      PER  unknown
# 63      287            lad          5        6     NOUN      man
# 64      287         Cedric          9       10    PROPN  unknown
# 65      287              I         12       13     PRON  unknown
# 66      295         Merlin          0        1      PER  unknown
# 67      295   Harry Potter          7        9      PER  unknown
# 68      295         Merlin          1        2    PROPN  unknown
# 69      295            You          6        7     PRON  unknown
# 70      295          Harry          9       10    PROPN  unknown
# 71      295         Potter         10       11    PROPN  unknown
# 72      300            you          4        5     PRON  unknown
# 73      305             it          3        4     PRON  unknown
# 74      309             we          3        4     PRON  unknown
# 75      310             We          1        2     PRON  unknown
# 76      315          there          5        6     PRON  unknown
# 77      315       yourself         10       11     PRON  unknown
# 78      318           they          3        4     PRON  unknown
# 79      321        Portkey         14       15     MISC  unknown
# 80      321             It         13       14     PRON  unknown
# 81      321        Portkey         16       17    PROPN  unknown
# 82      324           What          1        2     PRON  unknown
# 83      324        Portkey          4        5    PROPN  unknown
# 84      328        Harry !         11       13      PER  unknown
# 85      328          Harry         13       14    PROPN  unknown

# %% [markdown]
# TODO :
# - Match with character name
# - remove other notebooks
# - remove subtitles.py
# - remove unused function
# - get path syn dict from path
# - documentaiton
# - Test ?
