# %% [markdown]
# # Analyse subtitles of Harry Potter 4
#
# In this notebook we'll go throught Harry Potter 4 subtitles to see if we can find some entities in the text and if we can map it with characters.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

from bechdelai.nlp.process_srt import load_srt
from bechdelai.data.tmdb import get_movie_cast_from_id
from bechdelai.nlp.analyse_srt import extract_person_references_in_srt
from bechdelai.nlp.entities import match_entities_with_cast
# Out:
# 2023-01-22 16:34:32,159 loading file C:\Users\natha\.flair\models\ner-english\4f4cdab26f24cb98b732b389e6cebc646c36f54cfd6e0b7d3b90b25656e4262f.8baa8ae8795f4df80b28e7f7b61d788ecbb057d1dc85aacb316f1bd02837a4a4
# 2023-01-22 16:34:34,405 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>

# %%
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Load data

# %% [markdown]
# Srt file

# %%
fpath = "../../../data/srt/harry_potter_4.srt"
srt_list = load_srt(fpath)

# %%
for srt in srt_list[:2]:
    print(srt)
# Out:
# 1
# 00:01:46,125 --> 00:01:48,543
# Bloody kids.
#
# 2
# 00:02:35,007 --> 00:02:38,676
# How fastidious you've become,
# Wormtail.

# %% [markdown]
# TMDB meta data

# %%
tmdb_id = "674"
cast = get_movie_cast_from_id(tmdb_id)["cast"]

# %%
cast_df = pd.DataFrame(cast)
cast_df.head()
# Out:
#    adult  gender     id known_for_department              name  \
# 0  False       2  10980               Acting  Daniel Radcliffe
# 1  False       2  10989               Acting      Rupert Grint
# 2  False       1  10990               Acting       Emma Watson
# 3  False       2   1923               Acting   Robbie Coltrane
# 4  False       2   5469               Acting     Ralph Fiennes
#
#       original_name  popularity                      profile_path  cast_id  \
# 0  Daniel Radcliffe      48.452  /omfCyOCwgG26ajPp8NiaATgCeze.jpg        1
# 1      Rupert Grint      28.655  /q2KZZ0ltTEl7Sf8volNFV1JDEP4.jpg        2
# 2       Emma Watson      54.312  /tvPPRGzAzdQFhlKzLbMO1EpuTJI.jpg        3
# 3   Robbie Coltrane      14.129  /jOHs3xvlwRiiG2CLtso5zzmGCXg.jpg        7
# 4     Ralph Fiennes      62.183  /tJr9GcmGNHhLVVEH3i7QYbj6hBi.jpg        4
#
#           character                 credit_id  order
# 0      Harry Potter  52fe4268c3a36847f801c21d      0
# 1       Ron Weasley  52fe4268c3a36847f801c221      1
# 2  Hermione Granger  52fe4268c3a36847f801c225      2
# 3     Rubeus Hagrid  52fe4268c3a36847f801c235      3
# 4    Lord Voldemort  52fe4268c3a36847f801c229      4

# %% [markdown]
# ## Get entities and nouns

# %%
# %%time
results = extract_person_references_in_srt(srt_list)
# Out:
# Wall time: 8min 54s

# %%
results.sample(20)
# Out:
# 2023-01-22 16:43:33,148 loading file C:\Users\natha\.flair\models\ner-english\4f4cdab26f24cb98b732b389e6cebc646c36f54cfd6e0b7d3b90b25656e4262f.8baa8ae8795f4df80b28e7f7b61d788ecbb057d1dc85aacb316f1bd02837a4a4
# 2023-01-22 16:43:35,326 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
#       srt_id                                               text  start_sec  \
# 224      163    How can the Ministry\nnot know who conjured it?        875
# 1117     737  ...is none other than the\nBulgarian bonbon, V...       3971
# 600      417                                 How did you do it?       2315
# 2455    1578  ...when Voldemort's wand and mine\nsort of con...       8896
# 522      372                          Harry, for goodness sake.       2080
# 2067    1321                                           Sonorus!       7143
# 1353     881  Because we'd take the mickey out of her\nif sh...       4637
# 1231     809       Yeah, but, then again,\nhe can take himself.       4323
# 1621    1044        Not being a bad boy again,\nare you, Harry?       5592
# 1253     825                                    And I said yes!       4391
# 827      554                 You'll be glad you came. Trust me.       2916
# 899      596      He disagrees.\nHe thinks you won't last five.       3073
# 465      326                               We're gonna be late!       1765
# 1721    1121                           But she's my friend too!       6080
# 2276    1473       Cedric, he asked me\nto bring his body back.       8313
# 176      129                                      What is that?        754
# 693      486  I don't have much time,\nso let me get straigh...       2636
# 1786    1168  Not trying to lure Potter into one of\nthe Min...       6375
# 7          4                 Oh, no. No, no, my Lord Voldemort.        168
# 2122    1364                                    It's a Portkey.       7661
#
#       end_sec        ent  start_idx  end_idx ent_type   gender
# 224       877         it          8        9     PRON  unknown
# 1117     3975  Bulgarian          6        7     MISC  unknown
# 600      2317         it          4        5     PRON  unknown
# 2455     8900       mine          6        7     PRON  unknown
# 522      2082      Harry          0        1      PER  unknown
# 2067     7145    Sonorus          0        1    PROPN  unknown
# 1353     4639        her          8        9     PRON    woman
# 1231     4325    himself         10       11     PRON      man
# 1621     5594        boy          4        5     NOUN  unknown
# 1253     4393          I          1        2     PRON  unknown
# 827      2919         me          8        9     PRON  unknown
# 899      3076         He          0        1     PRON      man
# 465      1767         We          0        1     PRON  unknown
# 1721     6082        she          1        2     PRON    woman
# 2276     8315     Cedric          0        1      PER  unknown
# 176       756       What          0        1     PRON  unknown
# 693      2639         it         13       14     PRON  unknown
# 1786     6379     Potter          4        5      PER  unknown
# 7         171  Voldemort         10       11      PER  unknown
# 2122     7663    Portkey          3        4     MISC  unknown

# %%
len(results)
# Out:
# 2487

# %%
results_with_cast = match_entities_with_cast(results, cast_df)

# %%
results_with_cast.sample(20)
# Out:
#       srt_id                                               text  start_sec  \
# 292      209                  <i>Whether we be old and bald</i>       1169
# 1222     803                             - Hi, Harry.\n- Hello.       4277
# 785      533                   Dean was told by Parvati that...       2828
# 30        15  Step aside, Wormtail,\nso I can give our guest...        213
# 169      125                                             Harry!        740
# 189      137              - Crime?\n- Barty! They're just kids.        775
# 1023     676                                          Mr. Krum.       3414
# 1963    1262  Curiosity is not a sin, Harry.\nBut you should...       6855
# 799      538  Yeah, I brought the cloak.\nHagrid, where are ...       2853
# 1192     789  Blimey, Harry. You've slayed dragons.\nIf you ...       4200
# 681      474              We need to talk, Harry, face-to-face.       2566
# 1505     976                                             Lumus!       5194
# 1983    1272                             Sir? Mr. Crouch's son.       6894
# 1065     713        Caught on, have you?\nTook you long enough.       3865
# 523      373                                      He's a cheat!       2113
# 437      310  Stop it! Can't you see\nit's bothering him? St...       1645
# 1856    1206  In times like these, the wizard world looks\nt...       6553
# 2116    1358            Go on, take it.\nYou saved me, take it!       7620
# 2431    1558  The Ministry of Magic\ndoes not wish me to tel...       8791
# 758      522         Moody gave it to me.\nThat day we had tea.       2786
#
#       end_sec         ent  start_idx  end_idx ent_type   gender  \
# 292      1171          we          4        5     PRON  unknown
# 1222     4278       Harry          3        4      PER      man
# 785      2831     Parvati          4        5      PER    woman
# 30        219       guest         10       11     NOUN  unknown
# 169       742     Harry !          0        2      PER      man
# 189       777       Barty          4        5      PER      man
# 1023     3416         Mr.          0        1    PROPN  unknown
# 1963     6860       Harry          6        7      PER      man
# 799      2856           I          2        3     PRON  unknown
# 1192     4204        date         15       16     NOUN  unknown
# 681      2568          We          0        1     PRON  unknown
# 1505     5195       Lumus          0        1    PROPN  unknown
# 1983     6896      Crouch          3        4      PER      man
# 1065     3868         you          4        5     PRON  unknown
# 523      2114          He          0        1     PRON      man
# 437      1649          it          7        8     PRON  unknown
# 1856     6557  Dumbledore         15       16      PER      man
# 2116     7623          me          8        9     PRON  unknown
# 2431     8795          me          7        8     PRON  unknown
# 758      2789          it          2        3     PRON  unknown
#
#        character_found
# 292
# 1222      Harry Potter
# 785      Parvati Patil
# 30
# 169       Harry Potter
# 189       Barty Crouch
# 1023
# 1963      Harry Potter
# 799
# 1192
# 681
# 1505
# 1983      Barty Crouch
# 1065
# 523
# 437
# 1856  Albus Dumbledore
# 2116
# 2431
# 758
