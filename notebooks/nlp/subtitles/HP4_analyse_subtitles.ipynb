# %% [markdown]
# # Analyse HP 4 subtitles

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import packages

# %%
# %%time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from bechdelai.processing.process_srt import create_txt_blocks, load_srt
from bechdelai.processing.analyse_srt import extract_keyword, word_is_synonym_of_person
# Out:
# 2022-06-14 23:07:57,063 loading file C:\Users\natha\.flair\models\ner-english\4f4cdab26f24cb98b732b389e6cebc646c36f54cfd6e0b7d3b90b25656e4262f.8baa8ae8795f4df80b28e7f7b61d788ecbb057d1dc85aacb316f1bd02837a4a4
# 2022-06-14 23:08:00,345 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# CPU times: total: 17.8 s
# Wall time: 29.5 s

# %%
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Load data

# %%
fpath = "../../../data/srt/harry_potter_4.srt"

# %%
srt_list = load_srt(fpath)

# %% [markdown]
# ## Process srt to blocks

# %%
srt_blocks = create_txt_blocks(srt_list, second_gap=0)

# %%
srt_blocks[:3]
# Out:
# ["Bloody kids. How fastidious you've become, Wormtail.",
#  'As I recall, you once called the nearest gutter pipe home.',
#  'Could it be that the task of nursing me has become wearisome for you?']

# %% [markdown]
# ## Analyse

# %%
import json

# %%
dict_path = "../../../data/dictionary/syn_person.json"

# %%
with open(dict_path, "r") as f:
    person_syn_dict = json.load(f)

# %%
from bechdelai.scripts.scrap_dictionary import person_syn

# %%
import re

def def_with_person_syn(definition):
    """Returns whether the definition starts with
    a or an and a synonym of person
    """
    words_syn = "|".join(person_syn)
    pattern = f"^(a|an)((\s)|(\s[a-zA-Z]*\s))({words_syn})"
    
    return bool(re.match(pattern, definition))

def find_word_gender(definition):
    woman_pat = "^a (girl|woman)"
    man_pat = "^a (boy|man)"
    
    if re.match(woman_pat, definition):
        return "woman"
    elif re.match(man_pat, definition):
        return "man"
    else:
        return "unknown"

def process_syn_dict(person_syn_dict):

    person_syn_dict = {
        k: v 
        for k, v in person_syn_dict.items() 
        if def_with_person_syn(list(v["def"].values())[0][0])
    }
    
    for k, v in person_syn_dict.items():
        def_ = list(v["def"].values())[0][0]
        
        person_syn_dict[k]["gender"] = find_word_gender(def_)
        
    return person_syn_dict

person_syn_dict_ = process_syn_dict(person_syn_dict)

# %%
def time_to_sec(t):
    seconds = (t.hour * 60 + t.minute) * 60 + t.second
    return seconds

# %%
# %%time
results = []

for srt in srt_list:
    ent = extract_keyword(srt.text)
    
    entities = []
    for e in ent:
        ent_ = {}
        
        if e[3] == "NOUN":
            w = word_is_synonym_of_person(e[0], person_syn_dict_)
            if w:
                gender = person_syn_dict_[w]["gender"]
                ent_["entity"] = e[0]
                ent_["gender"] = gender
                
        elif e[3] == "PRON":
            if e[0].lower() in ['he', 'him', 'his', 'himself']:
                ent_["entity"] = e[0]
                ent_["gender"] = "man"
                            
            elif e[0].lower() in ['she', 'her', 'hers', 'herself']:
                ent_["entity"] = e[0]
                ent_["gender"] = "woman"
                
            else:
                ent_["entity"] = e[0]
                ent_["gender"] = "unknown"
                
        else:
            ent_["entity"] = e[0]
            ent_["gender"] = "unknown"
            
        if ent_:
            entities.append(ent_)
            
    if entities:
        results.append({
            "start_sec": time_to_sec(srt.start.to_time()),
            "end_sec": time_to_sec(srt.end.to_time()),
            "duration": time_to_sec(srt.duration.to_time()),
            "entities": entities
        })
# Out:
# CPU times: total: 1h 4min 18s
# Wall time: 8min 6s

# %%
for res in results:
    print(f"===== from {res['start_sec']}s to {res['end_sec']}s =====")
    print("Find following entities:")
    for ent in res["entities"]:
        ent_ = ent['entity'].replace('\n', ' ')
        print(f"\t- {ent_} (detected gender `{ent['gender'].upper()}`)")
    print()
# Out:
# ===== from 155s to 158s =====
# Find following entities:
# 	- Wormtail (detected gender `UNKNOWN`)
# 	- Wormtail (detected gender `UNKNOWN`)
#
# ===== from 163s to 168s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 168s to 171s =====
# Find following entities:
# 	- my Lord Voldemort (detected gender `UNKNOWN`)
#
# ===== from 172s to 175s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
# 	- it  (detected gender `UNKNOWN`)
# 	- the boy (detected gender `UNKNOWN`)
#
# ===== from 175s to 178s =====
# Find following entities:
# 	- The boy (detected gender `UNKNOWN`)
# 	- everything (detected gender `UNKNOWN`)
#
# ===== from 178s to 182s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- him (detected gender `MAN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 185s to 189s =====
# Find following entities:
# 	- Good (detected gender `UNKNOWN`)
#
# ===== from 192s to 194s =====
# Find following entities:
# 	- them (detected gender `UNKNOWN`)
#
# ===== from 206s to 209s =====
# Find following entities:
# 	- Nagini (detected gender `UNKNOWN`)
# 	- the old Muggle caretaker (detected gender `UNKNOWN`)
#
# ===== from 213s to 219s =====
# Find following entities:
# 	- Wormtail,  (detected gender `UNKNOWN`)
# 	- our guest (detected gender `UNKNOWN`)
#
# ===== from 219s to 221s =====
# Find following entities:
# 	- Avada Kedavra (detected gender `UNKNOWN`)
#
# ===== from 226s to 227s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 228s to 230s =====
# Find following entities:
# 	- Harry ! (detected gender `UNKNOWN`)
#
# ===== from 233s to 236s =====
# Find following entities:
# 	- Hermione (detected gender `UNKNOWN`)
#
# ===== from 239s to 241s =====
# Find following entities:
# 	- Last night (detected gender `UNKNOWN`)
#
# ===== from 241s to 243s =====
# Find following entities:
# 	- Ronald ! (detected gender `UNKNOWN`)
#
# ===== from 249s to 252s =====
# Find following entities:
# 	- Ron ! (detected gender `UNKNOWN`)
#
# ===== from 259s to 262s =====
# Find following entities:
# 	- - Ron, where are we actually going?  (detected gender `UNKNOWN`)
#
# ===== from 262s to 265s =====
# Find following entities:
# 	- Dad (detected gender `UNKNOWN`)
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 270s to 271s =====
# Find following entities:
# 	- Arthur ! (detected gender `UNKNOWN`)
#
# ===== from 272s to 274s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 274s to 278s =====
# Find following entities:
# 	- Amos (detected gender `UNKNOWN`)
# 	- us  (detected gender `UNKNOWN`)
#
# ===== from 278s to 284s =====
# Find following entities:
# 	- Amos Diggory, everyone (detected gender `UNKNOWN`)
# 	- me (detected gender `UNKNOWN`)
# 	- the Ministry (detected gender `UNKNOWN`)
#
# ===== from 284s to 287s =====
# Find following entities:
# 	- Cedric (detected gender `UNKNOWN`)
# 	- young lad  (detected gender `MAN`)
# 	- Cedric (detected gender `UNKNOWN`)
#
# ===== from 292s to 295s =====
# Find following entities:
# 	- Harry Potter (detected gender `UNKNOWN`)
# 	- Harry Potter (detected gender `UNKNOWN`)
#
# ===== from 295s to 298s =====
# Find following entities:
# 	- - Great, great pleasure (detected gender `UNKNOWN`)
#
# ===== from 302s to 305s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 307s to 309s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 309s to 310s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
#
# ===== from 311s to 315s =====
# Find following entities:
# 	- yourself (detected gender `UNKNOWN`)
#
# ===== from 316s to 318s =====
# Find following entities:
# 	- they all (detected gender `UNKNOWN`)
#
# ===== from 318s to 321s =====
# Find following entities:
# 	- just any manky old boot (detected gender `UNKNOWN`)
# 	- It (detected gender `UNKNOWN`)
# 	- a Portkey (detected gender `UNKNOWN`)
#
# ===== from 323s to 324s =====
# Find following entities:
# 	- a Portkey (detected gender `UNKNOWN`)
#
# ===== from 324s to 328s =====
# Find following entities:
# 	- Harry ! (detected gender `UNKNOWN`)
#
# ===== from 399s to 400s =====
# Find following entities:
# 	- - Ced (detected gender `UNKNOWN`)
#
# ===== from 401s to 402s =====
# Find following entities:
# 	- Cedric (detected gender `UNKNOWN`)
#
# ===== from 420s to 422s =====
# Find following entities:
# 	- Ginny (detected gender `UNKNOWN`)
# 	- Ginny (detected gender `UNKNOWN`)
#
# ===== from 426s to 429s =====
# Find following entities:
# 	- Ron (detected gender `UNKNOWN`)
# 	- We (detected gender `UNKNOWN`)
#
# ===== from 429s to 431s =====
# Find following entities:
# 	- Ron ! (detected gender `UNKNOWN`)
#
# ===== from 453s to 456s =====
# Find following entities:
# 	- your Quidditch World Cup  (detected gender `UNKNOWN`)
#
# ===== from 456s to 459s =====
# Find following entities:
# 	- Dad (detected gender `UNKNOWN`)
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 460s to 461s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 461s to 463s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 466s to 469s =====
# Find following entities:
# 	- Father and I (detected gender `UNKNOWN`)
# 	-  the minister's box (detected gender `UNKNOWN`)
#
# ===== from 472s to 474s =====
# Find following entities:
# 	- Draco (detected gender `UNKNOWN`)
#
# ===== from 479s to 482s =====
# Find following entities:
# 	- yourself (detected gender `UNKNOWN`)
#
# ===== from 506s to 508s =====
# Find following entities:
# 	- Troy ! (detected gender `UNKNOWN`)
# 	- It (detected gender `UNKNOWN`)
# 	- the Irish (detected gender `UNKNOWN`)
#
# ===== from 508s to 510s =====
# Find following entities:
# 	- - And Mullet!  (detected gender `UNKNOWN`)
# 	- - And Moran (detected gender `UNKNOWN`)
#
# ===== from 516s to 519s =====
# Find following entities:
# 	- Ireland (detected gender `UNKNOWN`)
# 	- Ireland (detected gender `UNKNOWN`)
# 	- Ireland (detected gender `UNKNOWN`)
#
# ===== from 523s to 526s =====
# Find following entities:
# 	- the Bulgarians (detected gender `UNKNOWN`)
#
# ===== from 535s to 538s =====
# Find following entities:
# 	- the best Seeker in the world (detected gender `UNKNOWN`)
#
# ===== from 540s to 543s =====
# Find following entities:
# 	- Krum (detected gender `UNKNOWN`)
# 	- Krum (detected gender `UNKNOWN`)
# 	- Krum (detected gender `UNKNOWN`)
#
# ===== from 548s to 549s =====
# Find following entities:
# 	- Krum (detected gender `UNKNOWN`)
#
# ===== from 561s to 564s =====
# Find following entities:
# 	- Minister for Magic... (detected gender `UNKNOWN`)
#
# ===== from 564s to 567s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
# 	- great pleasure (detected gender `UNKNOWN`)
#
# ===== from 568s to 572s =====
# Find following entities:
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 572s to 578s =====
# Find following entities:
# 	- the 422nd Quidditch World Cup (detected gender `UNKNOWN`)
#
# ===== from 588s to 590s =====
# Find following entities:
# 	- Krum (detected gender `UNKNOWN`)
# 	- Krum (detected gender `UNKNOWN`)
# 	- Krum (detected gender `UNKNOWN`)
#
# ===== from 600s to 601s =====
# Find following entities:
# 	- - Krum?  (detected gender `UNKNOWN`)
# 	- - Dumb Krum (detected gender `UNKNOWN`)
#
# ===== from 602s to 605s =====
# Find following entities:
# 	- He (detected gender `MAN`)
#
# ===== from 605s to 608s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- an athlete (detected gender `UNKNOWN`)
# 	- - Dumb Krum (detected gender `UNKNOWN`)
#
# ===== from 608s to 609s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- an artist (detected gender `UNKNOWN`)
#
# ===== from 609s to 612s =====
# Find following entities:
# 	- love (detected gender `UNKNOWN`)
# 	- Ron.  (detected gender `UNKNOWN`)
#
# ===== from 612s to 613s =====
# Find following entities:
# 	- Viktor (detected gender `UNKNOWN`)
#
# ===== from 613s to 615s =====
# Find following entities:
# 	- Viktor (detected gender `UNKNOWN`)
#
# ===== from 615s to 618s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 619s to 621s =====
# Find following entities:
# 	- the Irish  (detected gender `UNKNOWN`)
#
# ===== from 621s to 623s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 624s to 625s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- the Irish (detected gender `UNKNOWN`)
#
# ===== from 626s to 629s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
#
# ===== from 631s to 633s =====
# Find following entities:
# 	- Death Eaters ! (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
# 	- the Death Eaters (detected gender `UNKNOWN`)
#
# ===== from 633s to 637s =====
# Find following entities:
# 	- the Portkey, everybody, and stick together (detected gender `UNKNOWN`)
#
# ===== from 637s to 639s =====
# Find following entities:
# 	- Fred, George!  (detected gender `UNKNOWN`)
# 	- Ginny (detected gender `UNKNOWN`)
#
# ===== from 642s to 644s =====
# Find following entities:
# 	- Harry ! (detected gender `UNKNOWN`)
#
# ===== from 659s to 661s =====
# Find following entities:
# 	- Harry ! (detected gender `UNKNOWN`)
#
# ===== from 662s to 664s =====
# Find following entities:
# 	- Harry ! Harry ! (detected gender `UNKNOWN`)
#
# ===== from 712s to 713s =====
# Find following entities:
# 	- Morsmordre (detected gender `UNKNOWN`)
#
# ===== from 740s to 742s =====
# Find following entities:
# 	- Harry ! (detected gender `UNKNOWN`)
#
# ===== from 743s to 746s =====
# Find following entities:
# 	- Harry ! (detected gender `UNKNOWN`)
#
# ===== from 748s to 750s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 759s to 761s =====
# Find following entities:
# 	- Stupefy (detected gender `UNKNOWN`)
#
# ===== from 766s to 769s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
# 	- - Ron, Harry, Hermione, you all right?  (detected gender `UNKNOWN`)
# 	- We (detected gender `UNKNOWN`)
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 769s to 770s =====
# Find following entities:
# 	- you (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 770s to 772s =====
# Find following entities:
# 	- Crouch (detected gender `UNKNOWN`)
#
# ===== from 775s to 777s =====
# Find following entities:
# 	- They (detected gender `UNKNOWN`)
#
# ===== from 779s to 781s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- the Dark Mark, Harry (detected gender `UNKNOWN`)
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 781s to 783s =====
# Find following entities:
# 	- What, Voldemort (detected gender `UNKNOWN`)
#
# ===== from 784s to 788s =====
# Find following entities:
# 	- they (detected gender `UNKNOWN`)
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 799s to 801s =====
# Find following entities:
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 827s to 835s =====
# Find following entities:
# 	- Anything from the trolley (detected gender `UNKNOWN`)
#
# ===== from 843s to 845s =====
# Find following entities:
# 	- ...and a Licorice Wand (detected gender `UNKNOWN`)
#
# ===== from 846s to 848s =====
# Find following entities:
# 	- second thought, just the Drooble (detected gender `UNKNOWN`)
#
# ===== from 848s to 852s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
# 	- - Just the Drooble (detected gender `UNKNOWN`)
#
# ===== from 854s to 856s =====
# Find following entities:
# 	- Two Pumpkin Pasties (detected gender `UNKNOWN`)
#
# ===== from 864s to 866s =====
# Find following entities:
# 	- Anything sweet for you, dear (detected gender `UNKNOWN`)
#
# ===== from 870s to 872s =====
# Find following entities:
# 	- Anything from the trolley (detected gender `UNKNOWN`)
#
# ===== from 875s to 877s =====
# Find following entities:
# 	- the Ministry  (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 877s to 879s =====
# Find following entities:
# 	- any security (detected gender `UNKNOWN`)
#
# ===== from 879s to 882s =====
# Find following entities:
# 	- Loads, according to Dad (detected gender `UNKNOWN`)
#
# ===== from 882s to 886s =====
# Find following entities:
# 	- them (detected gender `UNKNOWN`)
#
# ===== from 889s to 892s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 896s to 899s =====
# Find following entities:
# 	- Sirius (detected gender `UNKNOWN`)
#
# ===== from 899s to 903s =====
# Find following entities:
# 	- the World Cup  (detected gender `UNKNOWN`)
#
# ===== from 912s to 915s =====
# Find following entities:
# 	- Hedwig (detected gender `UNKNOWN`)
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 962s to 965s =====
# Find following entities:
# 	- something you don't see every day (detected gender `UNKNOWN`)
#
# ===== from 989s to 993s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 1002s to 1004s =====
# Find following entities:
# 	- Hogwarts (detected gender `UNKNOWN`)
#
# ===== from 1005s to 1007s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1007s to 1008s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1011s to 1014s =====
# Find following entities:
# 	- them (detected gender `UNKNOWN`)
# 	- them (detected gender `UNKNOWN`)
#
# ===== from 1014s to 1020s =====
# Find following entities:
# 	- Hogwarts (detected gender `UNKNOWN`)
#
# ===== from 1020s to 1022s =====
# Find following entities:
# 	- The Triwizard Tournament (detected gender `UNKNOWN`)
#
# ===== from 1023s to 1025s =====
# Find following entities:
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 1025s to 1028s =====
# Find following entities:
# 	- the Triwizard Tournament  (detected gender `UNKNOWN`)
#
# ===== from 1053s to 1057s =====
# Find following entities:
# 	- Madame Maxime (detected gender `UNKNOWN`)
# 	- Madame Maxime (detected gender `UNKNOWN`)
#
# ===== from 1079s to 1082s =====
# Find following entities:
# 	- Blimey (detected gender `UNKNOWN`)
#
# ===== from 1135s to 1136s =====
# Find following entities:
# 	- Krum (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1137s to 1138s =====
# Find following entities:
# 	- Blimey (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
# 	- him (detected gender `MAN`)
#
# ===== from 1138s to 1140s =====
# Find following entities:
# 	- Viktor Krum (detected gender `UNKNOWN`)
#
# ===== from 1149s to 1150s =====
# Find following entities:
# 	- Albus (detected gender `UNKNOWN`)
#
# ===== from 1151s to 1152s =====
# Find following entities:
# 	- Igor (detected gender `UNKNOWN`)
#
# ===== from 1154s to 1157s =====
# Find following entities:
# 	- 's (detected gender `UNKNOWN`)
#
# ===== from 1159s to 1161s =====
# Find following entities:
# 	- Maestro (detected gender `UNKNOWN`)
#
# ===== from 1162s to 1165s =====
# Find following entities:
# 	- Hogwarts, Hogwarts, Hoggy Warty Hogwarts</i> (detected gender `UNKNOWN`)
#
# ===== from 1165s to 1168s =====
# Find following entities:
# 	- us (detected gender `UNKNOWN`)
# 	- something (detected gender `UNKNOWN`)
#
# ===== from 1169s to 1171s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 1171s to 1175s =====
# Find following entities:
# 	- knees</i (detected gender `UNKNOWN`)
#
# ===== from 1175s to 1178s =====
# Find following entities:
# 	- filling</i (detected gender `UNKNOWN`)
#
# ===== from 1181s to 1184s =====
# Find following entities:
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 1202s to 1206s =====
# Find following entities:
# 	- Professor Dumbly-dorr (detected gender `UNKNOWN`)
#
# ===== from 1206s to 1209s =====
# Find following entities:
# 	- Madame Maxime (detected gender `UNKNOWN`)
# 	- They (detected gender `UNKNOWN`)
# 	- Madame Maxime (detected gender `UNKNOWN`)
#
# ===== from 1209s to 1212s =====
# Find following entities:
# 	- them (detected gender `UNKNOWN`)
#
# ===== from 1212s to 1215s =====
# Find following entities:
# 	- you know, Monsieur Hagrid... (detected gender `UNKNOWN`)
#
# ===== from 1215s to 1218s =====
# Find following entities:
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 1255s to 1260s =====
# Find following entities:
# 	- the Ministry (detected gender `UNKNOWN`)
#
# ===== from 1261s to 1265s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
# 	- the head of the Department of International Magical Cooperation (detected gender `UNKNOWN`)
#
# ===== from 1265s to 1267s =====
# Find following entities:
# 	- Mr. Bartemius Crouch (detected gender `UNKNOWN`)
#
# ===== from 1282s to 1284s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- Mad-Eye Moody (detected gender `UNKNOWN`)
#
# ===== from 1285s to 1288s =====
# Find following entities:
# 	- - Alastor Moody? (detected gender `UNKNOWN`)
# 	- The Auror?  (detected gender `UNKNOWN`)
# 	- - Auror (detected gender `UNKNOWN`)
#
# ===== from 1289s to 1292s =====
# Find following entities:
# 	- Dark-wizard catcher (detected gender `UNKNOWN`)
# 	- him (detected gender `MAN`)
#
# ===== from 1293s to 1296s =====
# Find following entities:
# 	- He (detected gender `MAN`)
#
# ===== from 1308s to 1311s =====
# Find following entities:
# 	- - My dear old friend, thanks for coming. - Stupid ceiling (detected gender `UNKNOWN`)
#
# ===== from 1319s to 1321s =====
# Find following entities:
# 	- he (detected gender `MAN`)
#
# ===== from 1321s to 1324s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1334s to 1336s =====
# Find following entities:
# 	- the Ministry (detected gender `UNKNOWN`)
#
# ===== from 1340s to 1343s =====
# Find following entities:
# 	- the Triwizard Tournament (detected gender `UNKNOWN`)
#
# ===== from 1349s to 1353s =====
# Find following entities:
# 	- They (detected gender `UNKNOWN`)
#
# ===== from 1372s to 1375s =====
# Find following entities:
# 	- The Goblet of Fire (detected gender `UNKNOWN`)
#
# ===== from 1375s to 1378s =====
# Find following entities:
# 	- Anyone wishing to submit themselves to the tournament... (detected gender `UNKNOWN`)
#
# ===== from 1382s to 1385s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1392s to 1397s =====
# Find following entities:
# 	- the Triwizard Tournament (detected gender `UNKNOWN`)
#
# ===== from 1423s to 1425s =====
# Find following entities:
# 	- Alastor Moody (detected gender `UNKNOWN`)
#
# ===== from 1427s to 1429s =====
# Find following entities:
# 	- Ex-Auror... (detected gender `UNKNOWN`)
#
# ===== from 1433s to 1436s =====
# Find following entities:
# 	- ...and your new Defense Against the Dark Arts teacher (detected gender `UNKNOWN`)
#
# ===== from 1436s to 1440s =====
# Find following entities:
# 	- Dumbledore (detected gender `UNKNOWN`)
#
# ===== from 1440s to 1442s =====
# Find following entities:
# 	- Any questions (detected gender `UNKNOWN`)
#
# ===== from 1445s to 1447s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
# 	- the Dark Arts (detected gender `UNKNOWN`)
#
# ===== from 1451s to 1457s =====
# Find following entities:
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 1457s to 1460s =====
# Find following entities:
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 1460s to 1463s =====
# Find following entities:
# 	- they (detected gender `UNKNOWN`)
# 	- The use of any one of them (detected gender `UNKNOWN`)
#
# ===== from 1468s to 1470s =====
# Find following entities:
# 	- The Ministry (detected gender `UNKNOWN`)
#
# ===== from 1477s to 1479s =====
# Find following entities:
# 	- another place to put your chewing gum (detected gender `UNKNOWN`)
#
# ===== from 1479s to 1481s =====
# Find following entities:
# 	- ...besides the underside of your desk, Mr. Finnigan (detected gender `UNKNOWN`)
#
# ===== from 1482s to 1485s =====
# Find following entities:
# 	- the back of his head (detected gender `UNKNOWN`)
#
# ===== from 1490s to 1493s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 1493s to 1494s =====
# Find following entities:
# 	- - Weasley!  (detected gender `UNKNOWN`)
#
# ===== from 1499s to 1501s =====
# Find following entities:
# 	- us (detected gender `UNKNOWN`)
#
# ===== from 1501s to 1505s =====
# Find following entities:
# 	- my dad (detected gender `UNKNOWN`)
#
# ===== from 1505s to 1507s =====
# Find following entities:
# 	- The Imperius Curse (detected gender `UNKNOWN`)
#
# ===== from 1507s to 1510s =====
# Find following entities:
# 	- your father  (detected gender `MAN`)
#
# ===== from 1511s to 1513s =====
# Find following entities:
# 	- the Ministry (detected gender `UNKNOWN`)
#
# ===== from 1524s to 1525s =====
# Find following entities:
# 	- Hello (detected gender `UNKNOWN`)
#
# ===== from 1532s to 1534s =====
# Find following entities:
# 	- Engorgio (detected gender `UNKNOWN`)
#
# ===== from 1540s to 1543s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 1549s to 1550s =====
# Find following entities:
# 	- she (detected gender `WOMAN`)
#
# ===== from 1551s to 1552s =====
# Find following entities:
# 	- she (detected gender `WOMAN`)
#
# ===== from 1562s to 1564s =====
# Find following entities:
# 	- Talented (detected gender `UNKNOWN`)
# 	- she (detected gender `WOMAN`)
#
# ===== from 1564s to 1567s =====
# Find following entities:
# 	- her (detected gender `WOMAN`)
#
# ===== from 1569s to 1571s =====
# Find following entities:
# 	- herself (detected gender `WOMAN`)
#
# ===== from 1586s to 1590s =====
# Find following entities:
# 	- You-Know-Who (detected gender `UNKNOWN`)
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 1590s to 1592s =====
# Find following entities:
# 	- the influence of the Imperius Curse (detected gender `UNKNOWN`)
#
# ===== from 1595s to 1598s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 1604s to 1606s =====
# Find following entities:
# 	- Longbottom (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1610s to 1614s =====
# Find following entities:
# 	- Professor Sprout (detected gender `UNKNOWN`)
#
# ===== from 1618s to 1620s =====
# Find following entities:
# 	- The Cruciatus Curse (detected gender `UNKNOWN`)
#
# ===== from 1645s to 1649s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
# 	- him (detected gender `MAN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1667s to 1671s =====
# Find following entities:
# 	- us (detected gender `UNKNOWN`)
# 	- the last Unforgivable Curse, Miss Granger (detected gender `UNKNOWN`)
#
# ===== from 1676s to 1678s =====
# Find following entities:
# 	- Avada Kedavra (detected gender `UNKNOWN`)
#
# ===== from 1684s to 1688s =====
# Find following entities:
# 	- Only one person (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1688s to 1690s =====
# Find following entities:
# 	- he (detected gender `MAN`)
#
# ===== from 1722s to 1724s =====
# Find following entities:
# 	- he (detected gender `MAN`)
#
# ===== from 1728s to 1731s =====
# Find following entities:
# 	- he (detected gender `MAN`)
# 	- He (detected gender `MAN`)
#
# ===== from 1734s to 1738s =====
# Find following entities:
# 	- Neville (detected gender `UNKNOWN`)
# 	- them (detected gender `UNKNOWN`)
#
# ===== from 1741s to 1743s =====
# Find following entities:
# 	- Neville (detected gender `UNKNOWN`)
#
# ===== from 1743s to 1744s =====
# Find following entities:
# 	- Son (detected gender `UNKNOWN`)
#
# ===== from 1747s to 1751s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
# 	- something (detected gender `UNKNOWN`)
#
# ===== from 1765s to 1767s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
#
# ===== from 1781s to 1783s =====
# Find following entities:
# 	- Cedric (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1799s to 1801s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1804s to 1806s =====
# Find following entities:
# 	- me (detected gender `UNKNOWN`)
#
# ===== from 1812s to 1815s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1816s to 1818s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 1819s to 1821s =====
# Find following entities:
# 	- Granger (detected gender `UNKNOWN`)
#
# ===== from 1822s to 1825s =====
# Find following entities:
# 	- an Age Line (detected gender `UNKNOWN`)
#
# ===== from 1825s to 1827s =====
# Find following entities:
# 	- Dumbledore (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
# 	- himself (detected gender `MAN`)
#
# ===== from 1830s to 1833s =====
# Find following entities:
# 	- a genius like Dumbledore  (detected gender `UNKNOWN`)
#
# ===== from 1837s to 1841s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 1843s to 1845s =====
# Find following entities:
# 	- Fred ? (detected gender `UNKNOWN`)
# 	- George (detected gender `UNKNOWN`)
# 	- George (detected gender `UNKNOWN`)
#
# ===== from 1882s to 1884s =====
# Find following entities:
# 	- Fight ! Fight ! Fight ! (detected gender `UNKNOWN`)
#
# ===== from 1889s to 1891s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
#
# ===== from 1934s to 1936s =====
# Find following entities:
# 	- The champion selection (detected gender `UNKNOWN`)
#
# ===== from 1967s to 1971s =====
# Find following entities:
# 	- Viktor Krum (detected gender `UNKNOWN`)
# 	- The Durmstrang champion  (detected gender `UNKNOWN`)
# 	- Viktor Krum (detected gender `UNKNOWN`)
#
# ===== from 1987s to 1989s =====
# Find following entities:
# 	- The champion for Beauxbatons... (detected gender `UNKNOWN`)
#
# ===== from 1990s to 1992s =====
# Find following entities:
# 	- Fleur Delacour (detected gender `UNKNOWN`)
#
# ===== from 2015s to 2020s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
#
# ===== from 2020s to 2024s =====
# Find following entities:
# 	- only one (detected gender `UNKNOWN`)
#
# ===== from 2024s to 2027s =====
# Find following entities:
# 	- Only one (detected gender `UNKNOWN`)
#
# ===== from 2031s to 2033s =====
# Find following entities:
# 	- ...the Triwizard Cup (detected gender `UNKNOWN`)
#
# ===== from 2064s to 2066s =====
# Find following entities:
# 	- Harry Potter (detected gender `UNKNOWN`)
#
# ===== from 2068s to 2069s =====
# Find following entities:
# 	- Harry Potter (detected gender `UNKNOWN`)
#
# ===== from 2076s to 2078s =====
# Find following entities:
# 	- Harry Potter (detected gender `UNKNOWN`)
#
# ===== from 2078s to 2080s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 2080s to 2082s =====
# Find following entities:
# 	- Harry, for goodness sake (detected gender `UNKNOWN`)
#
# ===== from 2113s to 2114s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- a cheat (detected gender `UNKNOWN`)
#
# ===== from 2115s to 2117s =====
# Find following entities:
# 	- He (detected gender `MAN`)
#
# ===== from 2145s to 2149s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 2149s to 2152s =====
# Find following entities:
# 	- Everything (detected gender `UNKNOWN`)
#
# ===== from 2152s to 2154s =====
# Find following entities:
# 	- Everything (detected gender `UNKNOWN`)
#
# ===== from 2154s to 2155s =====
# Find following entities:
# 	- - Harry.  (detected gender `UNKNOWN`)
#
# ===== from 2156s to 2157s =====
# Find following entities:
# 	- the Goblet of Fire (detected gender `UNKNOWN`)
#
# ===== from 2160s to 2161s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 2165s to 2167s =====
# Find following entities:
# 	- he (detected gender `MAN`)
# 	- he (detected gender `MAN`)
#
# ===== from 2167s to 2170s =====
# Find following entities:
# 	- The Goblet of Fire (detected gender `UNKNOWN`)
#
# ===== from 2170s to 2173s =====
# Find following entities:
# 	- Confundus Charm (detected gender `UNKNOWN`)
# 	- Confundus Charm (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2178s to 2182s =====
# Find following entities:
# 	- Karkaroff (detected gender `UNKNOWN`)
# 	- It (detected gender `UNKNOWN`)
# 	- Karkaroff (detected gender `UNKNOWN`)
#
# ===== from 2182s to 2185s =====
# Find following entities:
# 	- Alastor (detected gender `UNKNOWN`)
# 	- Alastor (detected gender `UNKNOWN`)
#
# ===== from 2187s to 2189s =====
# Find following entities:
# 	- Barty (detected gender `UNKNOWN`)
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 2194s to 2197s =====
# Find following entities:
# 	- The Goblet of Fire (detected gender `UNKNOWN`)
#
# ===== from 2199s to 2201s =====
# Find following entities:
# 	- Mr. Potter (detected gender `UNKNOWN`)
#
# ===== from 2202s to 2204s =====
# Find following entities:
# 	- He (detected gender `MAN`)
#
# ===== from 2206s to 2208s =====
# Find following entities:
# 	- a Triwizard champion (detected gender `UNKNOWN`)
#
# ===== from 2236s to 2238s =====
# Find following entities:
# 	- Albus (detected gender `UNKNOWN`)
#
# ===== from 2238s to 2241s =====
# Find following entities:
# 	- First the Dark Mark (detected gender `UNKNOWN`)
#
# ===== from 2241s to 2243s =====
# Find following entities:
# 	- Minerva (detected gender `UNKNOWN`)
#
# ===== from 2245s to 2247s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2247s to 2249s =====
# Find following entities:
# 	- Potter (detected gender `UNKNOWN`)
#
# ===== from 2249s to 2252s =====
# Find following entities:
# 	- Barty (detected gender `UNKNOWN`)
#
# ===== from 2252s to 2255s =====
# Find following entities:
# 	- the devil with Barty and his rules (detected gender `UNKNOWN`)
#
# ===== from 2255s to 2257s =====
# Find following entities:
# 	- the Ministry (detected gender `UNKNOWN`)
#
# ===== from 2258s to 2262s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2262s to 2266s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 2266s to 2269s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 2270s to 2273s =====
# Find following entities:
# 	- them (detected gender `UNKNOWN`)
#
# ===== from 2273s to 2275s =====
# Find following entities:
# 	- nothing (detected gender `UNKNOWN`)
#
# ===== from 2275s to 2277s =====
# Find following entities:
# 	- him (detected gender `MAN`)
#
# ===== from 2278s to 2281s =====
# Find following entities:
# 	- Potter (detected gender `UNKNOWN`)
#
# ===== from 2282s to 2284s =====
# Find following entities:
# 	- Severus (detected gender `UNKNOWN`)
#
# ===== from 2285s to 2288s =====
# Find following entities:
# 	- Alastor (detected gender `UNKNOWN`)
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 2288s to 2290s =====
# Find following entities:
# 	- him (detected gender `MAN`)
#
# ===== from 2291s to 2294s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2297s to 2300s =====
# Find following entities:
# 	- we all (detected gender `UNKNOWN`)
#
# ===== from 2315s to 2317s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2318s to 2323s =====
# Find following entities:
# 	- your best friend (detected gender `UNKNOWN`)
#
# ===== from 2326s to 2329s =====
# Find following entities:
# 	- Ron (detected gender `UNKNOWN`)
#
# ===== from 2334s to 2337s =====
# Find following entities:
# 	- Harry Potter (detected gender `UNKNOWN`)
# 	- Ron Weasley,  (detected gender `UNKNOWN`)
# 	- Harry Potter's stupid friend (detected gender `UNKNOWN`)
#
# ===== from 2343s to 2347s =====
# Find following entities:
# 	- I just wanna (detected gender `UNKNOWN`)
#
# ===== from 2354s to 2355s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 2387s to 2388s =====
# Find following entities:
# 	- Hello (detected gender `UNKNOWN`)
#
# ===== from 2389s to 2392s =====
# Find following entities:
# 	- Rita Skeeter (detected gender `UNKNOWN`)
#
# ===== from 2392s to 2395s =====
# Find following entities:
# 	- the Daily Prophet (detected gender `UNKNOWN`)
#
# ===== from 2395s to 2400s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 2403s to 2407s =====
# Find following entities:
# 	- lurk  (detected gender `UNKNOWN`)
#
# ===== from 2414s to 2417s =====
# Find following entities:
# 	- a champion (detected gender `UNKNOWN`)
#
# ===== from 2418s to 2422s =====
# Find following entities:
# 	- Myself & l (detected gender `UNKNOWN`)
#
# ===== from 2428s to 2430s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 2445s to 2447s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 2450s to 2452s =====
# Find following entities:
# 	- Quick-Quotes Quill , do you ? (detected gender `UNKNOWN`)
#
# ===== from 2454s to 2456s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 2457s to 2460s =====
# Find following entities:
# 	- a mere boy of 12 (detected gender `UNKNOWN`)
#
# ===== from 2465s to 2468s =====
# Find following entities:
# 	- yourself (detected gender `UNKNOWN`)
#
# ===== from 2477s to 2480s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2482s to 2485s =====
# Find following entities:
# 	- no ordinary boy of 12 (detected gender `UNKNOWN`)
#
# ===== from 2485s to 2487s =====
# Find following entities:
# 	- - Your story's legend (detected gender `UNKNOWN`)
#
# ===== from 2488s to 2490s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2500s to 2501s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
# 	- Everyone (detected gender `UNKNOWN`)
#
# ===== from 2506s to 2510s =====
# Find following entities:
# 	- they (detected gender `UNKNOWN`)
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 2557s to 2560s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
# 	- Hedwig (detected gender `UNKNOWN`)
#
# ===== from 2560s to 2563s =====
# Find following entities:
# 	- the World Cup (detected gender `UNKNOWN`)
# 	- the Ministry's  (detected gender `UNKNOWN`)
#
# ===== from 2563s to 2565s =====
# Find following entities:
# 	- she (detected gender `WOMAN`)
#
# ===== from 2566s to 2568s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
# 	- Harry, face-to-face (detected gender `UNKNOWN`)
#
# ===== from 2577s to 2578s =====
# Find following entities:
# 	- P.S. (detected gender `UNKNOWN`)
#
# ===== from 2609s to 2611s =====
# Find following entities:
# 	- Harry Potter, age 12... (detected gender `UNKNOWN`)
#
# ===== from 2611s to 2614s =====
# Find following entities:
# 	- ...suspect entrant in the Triwizard Tournament (detected gender `UNKNOWN`)
#
# ===== from 2634s to 2636s =====
# Find following entities:
# 	- Sirius (detected gender `UNKNOWN`)
#
# ===== from 2636s to 2639s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2639s to 2642s =====
# Find following entities:
# 	- the Goblet of Fire (detected gender `UNKNOWN`)
#
# ===== from 2646s to 2651s =====
# Find following entities:
# 	- Wormtail (detected gender `UNKNOWN`)
# 	- Wormtail and Voldemort (detected gender `UNKNOWN`)
#
# ===== from 2659s to 2663s =====
# Find following entities:
# 	- Voldemort (detected gender `UNKNOWN`)
# 	- him (detected gender `MAN`)
# 	- Something important (detected gender `UNKNOWN`)
#
# ===== from 2667s to 2668s =====
# Find following entities:
# 	- He (detected gender `MAN`)
#
# ===== from 2671s to 2675s =====
# Find following entities:
# 	- he (detected gender `MAN`)
# 	- me (detected gender `UNKNOWN`)
#
# ===== from 2676s to 2678s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2680s to 2682s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 2683s to 2684s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 2688s to 2692s =====
# Find following entities:
# 	- Hogwarts (detected gender `UNKNOWN`)
#
# ===== from 2693s to 2698s =====
# Find following entities:
# 	- Igor Karkaroff (detected gender `UNKNOWN`)
# 	- Igor Karkaroff (detected gender `UNKNOWN`)
#
# ===== from 2698s to 2702s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- a Death Eater (detected gender `UNKNOWN`)
# 	- a Death Eater (detected gender `UNKNOWN`)
#
# ===== from 2703s to 2708s =====
# Find following entities:
# 	- Barty Crouch (detected gender `UNKNOWN`)
# 	- Azkaban (detected gender `UNKNOWN`)
# 	- Azkaban (detected gender `UNKNOWN`)
#
# ===== from 2713s to 2715s =====
# Find following entities:
# 	- them  (detected gender `UNKNOWN`)
#
# ===== from 2717s to 2721s =====
# Find following entities:
# 	- no friend (detected gender `UNKNOWN`)
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 2722s to 2725s =====
# Find following entities:
# 	- Sirius (detected gender `UNKNOWN`)
#
# ===== from 2729s to 2731s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
# 	- - Someone's (detected gender `UNKNOWN`)
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 2736s to 2739s =====
# Find following entities:
# 	- anyone (detected gender `UNKNOWN`)
#
# ===== from 2777s to 2780s =====
# Find following entities:
# 	- - Neville (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2783s to 2786s =====
# Find following entities:
# 	- "Magical Water Plants of the Highland Lochs" (detected gender `UNKNOWN`)
#
# ===== from 2786s to 2789s =====
# Find following entities:
# 	- Moody (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
# 	- me (detected gender `UNKNOWN`)
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 2791s to 2793s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 2793s to 2795s =====
# Find following entities:
# 	- him (detected gender `MAN`)
# 	- yourself (detected gender `UNKNOWN`)
#
# ===== from 2796s to 2799s =====
# Find following entities:
# 	- Ron (detected gender `UNKNOWN`)
#
# ===== from 2805s to 2810s =====
# Find following entities:
# 	- Ronald (detected gender `UNKNOWN`)
# 	- Seamus (detected gender `UNKNOWN`)
# 	- Seamus (detected gender `UNKNOWN`)
# 	- him (detected gender `MAN`)
#
# ===== from 2810s to 2814s =====
# Find following entities:
# 	- Dean (detected gender `UNKNOWN`)
# 	- Hagrid (detected gender `UNKNOWN`)
# 	- Parvati  (detected gender `UNKNOWN`)
# 	- Hagrid (detected gender `UNKNOWN`)
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 2823s to 2826s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2828s to 2831s =====
# Find following entities:
# 	- Dean (detected gender `UNKNOWN`)
# 	- Parvati (detected gender `UNKNOWN`)
#
# ===== from 2833s to 2835s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2835s to 2837s =====
# Find following entities:
# 	- Hagrid (detected gender `UNKNOWN`)
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 2837s to 2840s =====
# Find following entities:
# 	- Ronald (detected gender `UNKNOWN`)
#
# ===== from 2853s to 2856s =====
# Find following entities:
# 	- Hagrid (detected gender `UNKNOWN`)
# 	- Hagrid (detected gender `UNKNOWN`)
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 2864s to 2866s =====
# Find following entities:
# 	- Hagrid (detected gender `UNKNOWN`)
#
# ===== from 2880s to 2882s =====
# Find following entities:
# 	- Hagrid (detected gender `UNKNOWN`)
#
# ===== from 2894s to 2898s =====
# Find following entities:
# 	- Hagrid (detected gender `UNKNOWN`)
# 	- - Bonsoir, Olympe.  (detected gender `UNKNOWN`)
# 	- Hagrid (detected gender `UNKNOWN`)
#
# ===== from 2905s to 2907s =====
# Find following entities:
# 	- Olympe (detected gender `UNKNOWN`)
#
# ===== from 2907s to 2909s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 2911s to 2914s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 2930s to 2932s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 2943s to 2945s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 2952s to 2957s =====
# Find following entities:
# 	- Horntail (detected gender `UNKNOWN`)
# 	- Horntail (detected gender `UNKNOWN`)
#
# ===== from 2958s to 2960s =====
# Find following entities:
# 	- Poor Ron (detected gender `UNKNOWN`)
# 	- him (detected gender `MAN`)
#
# ===== from 2962s to 2964s =====
# Find following entities:
# 	- Ron (detected gender `UNKNOWN`)
#
# ===== from 2964s to 2968s =====
# Find following entities:
# 	- him (detected gender `MAN`)
# 	- Romania (detected gender `UNKNOWN`)
#
# ===== from 2968s to 2969s =====
# Find following entities:
# 	- Ron (detected gender `UNKNOWN`)
#
# ===== from 2971s to 2973s =====
# Find following entities:
# 	- he (detected gender `MAN`)
#
# ===== from 2973s to 2975s =====
# Find following entities:
# 	- He (detected gender `MAN`)
#
# ===== from 2985s to 2988s =====
# Find following entities:
# 	- Potter (detected gender `UNKNOWN`)
# 	- Potter (detected gender `UNKNOWN`)
# 	- Potter (detected gender `UNKNOWN`)
#
# ===== from 3004s to 3006s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 3007s to 3008s =====
# Find following entities:
# 	- Potter ! (detected gender `UNKNOWN`)
#
# ===== from 3011s to 3013s =====
# Find following entities:
# 	- Potter (detected gender `UNKNOWN`)
#
# ===== from 3013s to 3016s =====
# Find following entities:
# 	- Potter (detected gender `UNKNOWN`)
# 	- Harry Potter (detected gender `UNKNOWN`)
# 	- Harry Potter (detected gender `UNKNOWN`)
#
# ===== from 3021s to 3025s =====
# Find following entities:
# 	- They (detected gender `UNKNOWN`)
# 	- us (detected gender `UNKNOWN`)
# 	- Ced (detected gender `UNKNOWN`)
#
# ===== from 3027s to 3031s =====
# Find following entities:
# 	- Fleur and Krum (detected gender `UNKNOWN`)
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 3031s to 3033s =====
# Find following entities:
# 	- Ced (detected gender `UNKNOWN`)
# 	- Ced (detected gender `UNKNOWN`)
# 	- him (detected gender `MAN`)
#
# ===== from 3033s to 3035s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 3035s to 3037s =====
# Find following entities:
# 	- Potter ! (detected gender `UNKNOWN`)
#
# ===== from 3037s to 3040s =====
# Find following entities:
# 	- them (detected gender `UNKNOWN`)
# 	- them (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 3041s to 3043s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 3044s to 3045s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 3053s to 3054s =====
# Find following entities:
# 	- Anything else (detected gender `UNKNOWN`)
#
# ===== from 3055s to 3058s =====
# Find following entities:
# 	- me (detected gender `UNKNOWN`)
#
# ===== from 3060s to 3064s =====
# Find following entities:
# 	- Potter (detected gender `UNKNOWN`)
# 	- Cheat.  (detected gender `UNKNOWN`)
#
# ===== from 3065s to 3067s =====
# Find following entities:
# 	- My father and I (detected gender `MAN`)
# 	- a bet (detected gender `UNKNOWN`)
#
# ===== from 3067s to 3071s =====
# Find following entities:
# 	- last 10 minutes in this tournament (detected gender `UNKNOWN`)
#
# ===== from 3073s to 3076s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- He (detected gender `MAN`)
#
# ===== from 3076s to 3079s =====
# Find following entities:
# 	- Malfoy (detected gender `UNKNOWN`)
# 	- your father (detected gender `MAN`)
# 	- Malfoy (detected gender `UNKNOWN`)
#
# ===== from 3080s to 3084s =====
# Find following entities:
# 	- He (detected gender `MAN`)
#
# ===== from 3090s to 3093s =====
# Find following entities:
# 	- someone when their back is turned (detected gender `UNKNOWN`)
#
# ===== from 3097s to 3099s =====
# Find following entities:
# 	- - Professor Moody!  (detected gender `UNKNOWN`)
#
# ===== from 3103s to 3107s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 3126s to 3128s =====
# Find following entities:
# 	- My father (detected gender `MAN`)
#
# ===== from 3128s to 3130s =====
# Find following entities:
# 	- - Professor Moody!  (detected gender `UNKNOWN`)
#
# ===== from 3130s to 3132s =====
# Find following entities:
# 	- Professor (detected gender `UNKNOWN`)
#
# ===== from 3132s to 3136s =====
# Find following entities:
# 	- stories about your father  (detected gender `MAN`)
#
# ===== from 3136s to 3139s =====
# Find following entities:
# 	- Alastor ! Alastor (detected gender `UNKNOWN`)
# 	- - Alastor (detected gender `UNKNOWN`)
# 	- Alastor.  (detected gender `UNKNOWN`)
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 3139s to 3143s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
#
# ===== from 3143s to 3145s =====
# Find following entities:
# 	- Dumbledore (detected gender `UNKNOWN`)
#
# ===== from 3145s to 3150s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- it (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 3156s to 3158s =====
# Find following entities:
# 	- me (detected gender `UNKNOWN`)
#
# ===== from 3193s to 3195s =====
# Find following entities:
# 	- a Foe-Glass (detected gender `UNKNOWN`)
#
# ===== from 3198s to 3203s =====
# Find following entities:
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 3210s to 3212s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 3231s to 3232s =====
# Find following entities:
# 	- Potter (detected gender `UNKNOWN`)
# 	- me (detected gender `UNKNOWN`)
#
# ===== from 3235s to 3239s =====
# Find following entities:
# 	- he (detected gender `MAN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 3240s to 3242s =====
# Find following entities:
# 	- Miss Delacour (detected gender `UNKNOWN`)
#
# ===== from 3242s to 3245s =====
# Find following entities:
# 	- She (detected gender `WOMAN`)
#
# ===== from 3245s to 3249s =====
# Find following entities:
# 	- Krum, his head  (detected gender `UNKNOWN`)
# 	- sawdust (detected gender `UNKNOWN`)
#
# ===== from 3249s to 3251s =====
# Find following entities:
# 	- Karkaroff (detected gender `UNKNOWN`)
#
# ===== from 3251s to 3253s =====
# Find following entities:
# 	- They (detected gender `UNKNOWN`)
#
# ===== from 3253s to 3257s =====
# Find following entities:
# 	- Krum (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 3262s to 3263s =====
# Find following entities:
# 	- Potter (detected gender `UNKNOWN`)
#
# ===== from 3293s to 3296s =====
# Find following entities:
# 	- Krum (detected gender `UNKNOWN`)
# 	- Any bets (detected gender `UNKNOWN`)
#
# ===== from 3298s to 3301s =====
# Find following entities:
# 	- Ten-to-1 for Fleur (detected gender `UNKNOWN`)
#
# ===== from 3303s to 3306s =====
# Find following entities:
# 	- a great day for all of us (detected gender `UNKNOWN`)
#
# ===== from 3316s to 3319s =====
# Find following entities:
# 	- any risks you may be exposed (detected gender `UNKNOWN`)
#
# ===== from 3319s to 3323s =====
# Find following entities:
# 	- Harry ? Is that you ? (detected gender `UNKNOWN`)
# 	- - Harry (detected gender `UNKNOWN`)
#
# ===== from 3323s to 3325s =====
# Find following entities:
# 	- we all (detected gender `UNKNOWN`)
#
# ===== from 3340s to 3342s =====
# Find following entities:
# 	- Young love (detected gender `UNKNOWN`)
#
# ===== from 3351s to 3354s =====
# Find following entities:
# 	- everything (detected gender `UNKNOWN`)
#
# ===== from 3366s to 3371s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 3381s to 3384s =====
# Find following entities:
# 	- you  (detected gender `UNKNOWN`)
#
# ===== from 3384s to 3387s =====
# Find following entities:
# 	- Miss Granger (detected gender `UNKNOWN`)
#
# ===== from 3390s to 3391s =====
# Find following entities:
# 	- Barty, the bag (detected gender `UNKNOWN`)
#
# ===== from 3394s to 3397s =====
# Find following entities:
# 	- Miss Delacour, over here (detected gender `UNKNOWN`)
# 	- Mr. Krum (detected gender `UNKNOWN`)
#
# ===== from 3397s to 3401s =====
# Find following entities:
# 	- Potter, Mr. Potter, over here.  (detected gender `UNKNOWN`)
#
# ===== from 3401s to 3404s =====
# Find following entities:
# 	- Miss Delacour, if you will (detected gender `UNKNOWN`)
#
# ===== from 3408s to 3410s =====
# Find following entities:
# 	- The Welsh Green (detected gender `UNKNOWN`)
#
# ===== from 3414s to 3416s =====
# Find following entities:
# 	- Mr. Krum (detected gender `UNKNOWN`)
#
# ===== from 3419s to 3421s =====
# Find following entities:
# 	- The Chinese Fireball (detected gender `UNKNOWN`)
#
# ===== from 3427s to 3429s =====
# Find following entities:
# 	- The Swedish Short-Snout (detected gender `UNKNOWN`)
#
# ===== from 3430s to 3432s =====
# Find following entities:
# 	- - The Horntail (detected gender `UNKNOWN`)
#
# ===== from 3432s to 3434s =====
# Find following entities:
# 	- - What's that, boy? - Nothing (detected gender `UNKNOWN`)
#
# ===== from 3438s to 3440s =====
# Find following entities:
# 	- The Hungarian Horntail (detected gender `UNKNOWN`)
#
# ===== from 3460s to 3461s =====
# Find following entities:
# 	- Any questions (detected gender `UNKNOWN`)
#
# ===== from 3465s to 3468s =====
# Find following entities:
# 	- Mr. Diggory (detected gender `UNKNOWN`)
#
# ===== from 3477s to 3480s =====
# Find following entities:
# 	- Diggory ! Diggory ! Diggory ! (detected gender `UNKNOWN`)
#
# ===== from 3496s to 3499s =====
# Find following entities:
# 	- them  (detected gender `UNKNOWN`)
#
# ===== from 3500s to 3503s =====
# Find following entities:
# 	- now our fourth and final contestant (detected gender `UNKNOWN`)
#
# ===== from 3505s to 3508s =====
# Find following entities:
# 	- Harry ! Harry ! Harry ! (detected gender `UNKNOWN`)
#
# ===== from 3575s to 3578s =====
# Find following entities:
# 	- Harry ! (detected gender `UNKNOWN`)
#
# ===== from 3579s to 3581s =====
# Find following entities:
# 	- Accio Firebolt (detected gender `UNKNOWN`)
#
# ===== from 3621s to 3622s =====
# Find following entities:
# ...
#
# ===== from 7503s to 7504s =====
# Find following entities:
# 	- Expelliarmus (detected gender `UNKNOWN`)
#
# ===== from 7514s to 7517s =====
# Find following entities:
# 	- Cedric (detected gender `UNKNOWN`)
# 	- He (detected gender `MAN`)
# 	- Cedric (detected gender `UNKNOWN`)
#
# ===== from 7517s to 7519s =====
# Find following entities:
# 	- me (detected gender `UNKNOWN`)
# 	- He (detected gender `MAN`)
#
# ===== from 7554s to 7567s =====
# Find following entities:
# 	- Harry ! (detected gender `UNKNOWN`)
#
# ===== from 7569s to 7571s =====
# Find following entities:
# 	- Reducto (detected gender `UNKNOWN`)
#
# ===== from 7591s to 7595s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 7596s to 7597s =====
# Find following entities:
# 	- I. (detected gender `UNKNOWN`)
#
# ===== from 7620s to 7623s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 7649s to 7650s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 7661s to 7663s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- a Portkey (detected gender `UNKNOWN`)
#
# ===== from 7665s to 7669s =====
# Find following entities:
# 	- - Harry (detected gender `UNKNOWN`)
# 	- a Portkey (detected gender `UNKNOWN`)
#
# ===== from 7671s to 7675s =====
# Find following entities:
# 	- Cedric (detected gender `UNKNOWN`)
# 	- We (detected gender `UNKNOWN`)
#
# ===== from 7682s to 7685s =====
# Find following entities:
# 	- - Harry (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 7695s to 7698s =====
# Find following entities:
# 	- Cedric ! (detected gender `UNKNOWN`)
# 	- - Avada Kedavra!  (detected gender `UNKNOWN`)
#
# ===== from 7709s to 7711s =====
# Find following entities:
# 	- Do it ! Now ! (detected gender `UNKNOWN`)
#
# ===== from 7766s to 7769s =====
# Find following entities:
# 	- The Dark Lord (detected gender `UNKNOWN`)
#
# ===== from 7850s to 7851s =====
# Find following entities:
# 	- Master (detected gender `UNKNOWN`)
#
# ===== from 7852s to 7854s =====
# Find following entities:
# 	- master (detected gender `UNKNOWN`)
#
# ===== from 7900s to 7903s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 7903s to 7909s =====
# Find following entities:
# 	- me  (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 7910s to 7913s =====
# Find following entities:
# 	- myself (detected gender `UNKNOWN`)
#
# ===== from 7915s to 7917s =====
# Find following entities:
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 7918s to 7921s =====
# Find following entities:
# 	- Macnair (detected gender `UNKNOWN`)
#
# ===== from 7922s to 7923s =====
# Find following entities:
# 	- Goyle (detected gender `UNKNOWN`)
#
# ===== from 7931s to 7933s =====
# Find following entities:
# 	- ...Lucius (detected gender `UNKNOWN`)
#
# ===== from 7935s to 7940s =====
# Find following entities:
# 	- My Lord (detected gender `UNKNOWN`)
# 	- any sign, a whisper of your whereabouts (detected gender `UNKNOWN`)
#
# ===== from 7940s to 7943s =====
# Find following entities:
# 	- signs, my slippery friend (detected gender `UNKNOWN`)
#
# ===== from 7943s to 7948s =====
# Find following entities:
# 	- my Lord (detected gender `UNKNOWN`)
#
# ===== from 7958s to 7960s =====
# Find following entities:
# 	- my true mask (detected gender `UNKNOWN`)
#
# ===== from 7970s to 7976s =====
# Find following entities:
# 	- Wormtail (detected gender `UNKNOWN`)
# 	- yourself (detected gender `UNKNOWN`)
# 	- Wormtail (detected gender `UNKNOWN`)
#
# ===== from 7981s to 7983s =====
# Find following entities:
# 	- master (detected gender `UNKNOWN`)
#
# ===== from 7989s to 7991s =====
# Find following entities:
# 	- him (detected gender `MAN`)
#
# ===== from 7992s to 7994s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 7997s to 8001s =====
# Find following entities:
# 	- the bones of my father (detected gender `MAN`)
#
# ===== from 8003s to 8007s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
# 	- me (detected gender `UNKNOWN`)
#
# ===== from 8010s to 8013s =====
# Find following entities:
# 	- The boy who lived (detected gender `UNKNOWN`)
#
# ===== from 8027s to 8028s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- love (detected gender `UNKNOWN`)
#
# ===== from 8028s to 8033s =====
# Find following entities:
# 	- when dear, sweet Lily Potter  (detected gender `UNKNOWN`)
#
# ===== from 8033s to 8036s =====
# Find following entities:
# 	- she (detected gender `WOMAN`)
#
# ===== from 8036s to 8038s =====
# Find following entities:
# 	- him (detected gender `MAN`)
#
# ===== from 8039s to 8041s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 8041s to 8044s =====
# Find following entities:
# 	- Something I should have foreseen (detected gender `UNKNOWN`)
#
# ===== from 8071s to 8074s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 8079s to 8081s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8085s to 8087s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 8088s to 8090s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 8090s to 8093s =====
# Find following entities:
# 	- Dumbledore (detected gender `UNKNOWN`)
# 	- he (detected gender `MAN`)
#
# ===== from 8094s to 8095s =====
# Find following entities:
# 	- bow (detected gender `UNKNOWN`)
#
# ===== from 8109s to 8111s =====
# Find following entities:
# 	- Attaboy, Harry (detected gender `UNKNOWN`)
#
# ===== from 8113s to 8117s =====
# Find following entities:
# 	- Especially your filthy Muggle mother (detected gender `UNKNOWN`)
#
# ===== from 8121s to 8124s =====
# Find following entities:
# 	- Harry Potter (detected gender `UNKNOWN`)
#
# ===== from 8137s to 8140s =====
# Find following entities:
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 8142s to 8146s =====
# Find following entities:
# 	- a merciful Lord (detected gender `UNKNOWN`)
#
# ===== from 8155s to 8157s =====
# Find following entities:
# 	- Harry Potter (detected gender `UNKNOWN`)
# 	- Harry Potter (detected gender `UNKNOWN`)
#
# ===== from 8157s to 8159s =====
# Find following entities:
# 	- me  (detected gender `UNKNOWN`)
#
# ===== from 8176s to 8178s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8179s to 8182s =====
# Find following entities:
# 	- - Expelliarmus!  (detected gender `UNKNOWN`)
# 	- - Avada Kedavra (detected gender `UNKNOWN`)
#
# ===== from 8199s to 8202s =====
# Find following entities:
# 	- nothing (detected gender `UNKNOWN`)
# 	- He (detected gender `MAN`)
#
# ===== from 8206s to 8208s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- mine (detected gender `UNKNOWN`)
#
# ===== from 8241s to 8245s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
# 	- the Portkey (detected gender `UNKNOWN`)
#
# ===== from 8245s to 8247s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
#
# ===== from 8251s to 8254s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 8254s to 8256s =====
# Find following entities:
# 	- my father (detected gender `MAN`)
#
# ===== from 8270s to 8272s =====
# Find following entities:
# 	- Accio (detected gender `UNKNOWN`)
#
# ===== from 8292s to 8294s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8295s to 8301s =====
# Find following entities:
# 	- Harry ! (detected gender `UNKNOWN`)
#
# ===== from 8306s to 8308s =====
# Find following entities:
# 	- Dumbledore (detected gender `UNKNOWN`)
#
# ===== from 8308s to 8310s =====
# Find following entities:
# 	- He (detected gender `MAN`)
# 	- He (detected gender `MAN`)
#
# ===== from 8311s to 8313s =====
# Find following entities:
# 	- Voldemort (detected gender `UNKNOWN`)
#
# ===== from 8313s to 8315s =====
# Find following entities:
# 	- Cedric (detected gender `UNKNOWN`)
# 	- he (detected gender `MAN`)
#
# ===== from 8315s to 8318s =====
# Find following entities:
# 	- him (detected gender `MAN`)
#
# ===== from 8318s to 8321s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
# 	- It (detected gender `UNKNOWN`)
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 8321s to 8323s =====
# Find following entities:
# 	- He (detected gender `MAN`)
#
# ===== from 8323s to 8327s =====
# Find following entities:
# 	- everybody (detected gender `UNKNOWN`)
# 	- A boy (detected gender `UNKNOWN`)
#
# ===== from 8330s to 8334s =====
# Find following entities:
# 	- Dumbledore (detected gender `UNKNOWN`)
#
# ===== from 8343s to 8345s =====
# Find following entities:
# 	- my boy (detected gender `UNKNOWN`)
#
# ===== from 8348s to 8350s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- my boy (detected gender `UNKNOWN`)
#
# ===== from 8366s to 8368s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 8423s to 8425s =====
# Find following entities:
# 	- Potter (detected gender `UNKNOWN`)
#
# ===== from 8425s to 8427s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8435s to 8437s =====
# Find following entities:
# 	- a Portkey (detected gender `UNKNOWN`)
#
# ===== from 8440s to 8442s =====
# Find following entities:
# 	- Someone (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8442s to 8444s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8445s to 8446s =====
# Find following entities:
# 	- he (detected gender `MAN`)
#
# ===== from 8446s to 8448s =====
# Find following entities:
# 	- The Dark Lord (detected gender `UNKNOWN`)
#
# ===== from 8450s to 8454s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8459s to 8462s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
#
# ===== from 8496s to 8500s =====
# Find following entities:
# 	- anything about a graveyard, professor (detected gender `UNKNOWN`)
#
# ===== from 8507s to 8511s =====
# Find following entities:
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 8518s to 8520s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8524s to 8527s =====
# Find following entities:
# 	- Cedric Diggory (detected gender `UNKNOWN`)
#
# ===== from 8528s to 8530s =====
# Find following entities:
# 	- him (detected gender `MAN`)
# 	- myself (detected gender `UNKNOWN`)
#
# ===== from 8532s to 8534s =====
# Find following entities:
# 	- Neville Longbottom,  (detected gender `UNKNOWN`)
#
# ===== from 8535s to 8538s =====
# Find following entities:
# 	- him (detected gender `MAN`)
#
# ===== from 8538s to 8540s =====
# Find following entities:
# 	- him (detected gender `MAN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8548s to 8552s =====
# Find following entities:
# 	- It (detected gender `UNKNOWN`)
# 	- the Goblet of Fire (detected gender `UNKNOWN`)
#
# ===== from 8553s to 8556s =====
# Find following entities:
# 	- Krum (detected gender `UNKNOWN`)
#
# ===== from 8556s to 8558s =====
# Find following entities:
# 	- Potter (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8559s to 8563s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8566s to 8570s =====
# Find following entities:
# 	- The blood that runs through these veins runs within the Dark Lord (detected gender `UNKNOWN`)
#
# ===== from 8579s to 8582s =====
# Find following entities:
# 	- he (detected gender `MAN`)
# 	- he (detected gender `MAN`)
#
# ===== from 8586s to 8591s =====
# Find following entities:
# 	- the great Harry Potter (detected gender `UNKNOWN`)
#
# ===== from 8591s to 8592s =====
# Find following entities:
# 	- Expelliarmus (detected gender `UNKNOWN`)
#
# ===== from 8597s to 8598s =====
# Find following entities:
# 	- Severus (detected gender `UNKNOWN`)
#
# ===== from 8600s to 8602s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8604s to 8607s =====
# Find following entities:
# 	- - Albus Dumbledore (detected gender `UNKNOWN`)
#
# ===== from 8607s to 8610s =====
# Find following entities:
# 	- Alastor Moody ? Are you ? (detected gender `UNKNOWN`)
#
# ===== from 8610s to 8613s =====
# Find following entities:
# 	- he (detected gender `MAN`)
# 	- he (detected gender `MAN`)
#
# ===== from 8617s to 8618s =====
# Find following entities:
# 	- Harry, away from there (detected gender `UNKNOWN`)
#
# ===== from 8639s to 8642s =====
# Find following entities:
# 	- Alastor ? (detected gender `UNKNOWN`)
# 	- Albus (detected gender `UNKNOWN`)
# 	- Albus (detected gender `UNKNOWN`)
#
# ===== from 8643s to 8645s =====
# Find following entities:
# 	- Moody (detected gender `UNKNOWN`)
#
# ===== from 8647s to 8648s =====
# Find following entities:
# 	- Polyjuice Potion (detected gender `UNKNOWN`)
#
# ===== from 8648s to 8652s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 8652s to 8654s =====
# Find following entities:
# 	- We (detected gender `UNKNOWN`)
#
# ===== from 8688s to 8690s =====
# Find following entities:
# 	- Harry ! (detected gender `UNKNOWN`)
#
# ===== from 8693s to 8696s =====
# Find following entities:
# 	- Barty Crouch Junior (detected gender `UNKNOWN`)
#
# ===== from 8696s to 8699s =====
# Find following entities:
# 	- mine  (detected gender `UNKNOWN`)
# 	- yours (detected gender `UNKNOWN`)
#
# ===== from 8710s to 8711s =====
# Find following entities:
# 	- He (detected gender `MAN`)
#
# ===== from 8712s to 8714s =====
# Find following entities:
# 	- Lord Voldemort (detected gender `UNKNOWN`)
#
# ===== from 8715s to 8718s =====
# Find following entities:
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 8718s to 8722s =====
# Find following entities:
# 	- they (detected gender `UNKNOWN`)
# 	- they (detected gender `UNKNOWN`)
#
# ===== from 8723s to 8725s =====
# Find following entities:
# 	- a hero (detected gender `UNKNOWN`)
#
# ===== from 8749s to 8751s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 8757s to 8760s =====
# Find following entities:
# 	- Cedric Diggory (detected gender `UNKNOWN`)
#
# ===== from 8769s to 8773s =====
# Find following entities:
# 	- ...a fierce, fierce friend (detected gender `UNKNOWN`)
#
# ===== from 8784s to 8786s =====
# Find following entities:
# 	- Cedric Diggory (detected gender `UNKNOWN`)
#
# ===== from 8787s to 8789s =====
# Find following entities:
# 	- Lord Voldemort (detected gender `UNKNOWN`)
#
# ===== from 8791s to 8795s =====
# Find following entities:
# 	- The Ministry of Magic  (detected gender `UNKNOWN`)
#
# ===== from 8803s to 8807s =====
# Find following entities:
# 	- we all (detected gender `UNKNOWN`)
#
# ===== from 8807s to 8808s =====
# Find following entities:
# 	- us (detected gender `UNKNOWN`)
#
# ===== from 8808s to 8812s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 8824s to 8830s =====
# Find following entities:
# 	- Cedric Diggory  (detected gender `UNKNOWN`)
#
# ===== from 8833s to 8836s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
# 	- a boy who was (detected gender `UNKNOWN`)
#
# ===== from 8836s to 8839s =====
# Find following entities:
# 	- ...kind and honest... (detected gender `UNKNOWN`)
#
# ===== from 8872s to 8875s =====
# Find following entities:
# 	- them (detected gender `UNKNOWN`)
#
# ===== from 8902s to 8904s =====
# Find following entities:
# 	- Priori Incantatem (detected gender `UNKNOWN`)
#
# ===== from 8912s to 8913s =====
# Find following entities:
# 	- They (detected gender `UNKNOWN`)
#
# ===== from 8915s to 8919s =====
# Find following entities:
# 	- Harry (detected gender `UNKNOWN`)
#
# ===== from 8924s to 8929s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 8961s to 8963s =====
# Find following entities:
# 	- Hermione (detected gender `UNKNOWN`)
#
# ===== from 8963s to 8965s =====
# Find following entities:
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 8966s to 8968s =====
# Find following entities:
# 	- me (detected gender `UNKNOWN`)
#
# ===== from 8969s to 8970s =====
# Find following entities:
# 	- Bye (detected gender `UNKNOWN`)
#
# ===== from 9022s to 9025s =====
# Find following entities:
# 	- we (detected gender `UNKNOWN`)
#
# ===== from 9035s to 9038s =====
# Find following entities:
# 	- Everything (detected gender `UNKNOWN`)
# 	- it (detected gender `UNKNOWN`)
#
# ===== from 9051s to 9055s =====
# Find following entities:
# 	- you (detected gender `UNKNOWN`)
#
# ===== from 9059s to 9063s =====
# Find following entities:
# 	- - Harry (detected gender `UNKNOWN`)
