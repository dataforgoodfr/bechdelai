# %% [markdown]
# # Extract subtitles

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
from bechdelai.data.opensubtitles import search
from bechdelai.data.opensubtitles import get_subtitle_link
from bechdelai.data.opensubtitles import download_subtitle_from_url
from bechdelai.data.opensubtitles import get_subtitles_from_movie

# %% [markdown]
# ## Search

# %%
import chardet
import pysrt
import requests
from bs4 import BeautifulSoup

BASE_URL = "https://www.opensubtitles.org"

def get_subtitle_link(search_url: str) -> str:
    """Get the first subtitle link from the search url

    Args:
        search_url (str): the search url to get the subtitle link from

    Returns:
        str: the subtitle download link from the search url
    """
    try:
        response = requests.get(search_url)
        response.raise_for_status()
    except requests.exceptions.HTTPError as errh:
        raise Exception("Http Error:", errh)
    except requests.exceptions.ConnectionError as errc:
        raise Exception("Error Connecting:", errc)
    except requests.exceptions.Timeout as errt:
        raise Exception("Timeout Error:", errt)
    except requests.exceptions.RequestException as err:
        raise Exception("OOps: Something Else", err)

    soup = BeautifulSoup(response.text, "html.parser")
    download_link = soup.select("a[href*=subtitleserve]")
    if not download_link:
        return ""

    return list(map(lambda x: f"{BASE_URL}{x.get('href')}", download_link))

# %%
from time import sleep

# %%
SEARCH_URL = "https://www.opensubtitles.org/en/search/sublanguageid-eng"
url = SEARCH_URL
n_max = 5_000
offset = 0
all_url = []

while offset < n_max:
    sleep(1) 
    print(url)
    r = get_subtitle_link(url)
    all_url.extend(r)

    offset += len(r)
    url = f"{SEARCH_URL}/offset-{offset}"
# Out:
# https://www.opensubtitles.org/en/search/sublanguageid-eng
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-40
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-80
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-120
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-160
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-200
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-240
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-280
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-320
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-360
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-400
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-440
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-480
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-520
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-560
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-600
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-640
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-680
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-720
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-760
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-800
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-840
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-880
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-920
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-960
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1000
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1040
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1080
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1120
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1160
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1200
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1240
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1280
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1320
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1360
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1400
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1440
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1480
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1520
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1560
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1600
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1640
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1680
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1720
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1760
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1800
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1840
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1880
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1920
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-1960
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2000
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2040
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2080
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2120
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2160
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2200
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2240
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2280
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2320
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2360
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2400
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2440
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2480
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2520
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2560
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2600
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2640
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2680
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2720
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2760
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2800
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2840
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2880
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2920
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-2960
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3000
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3040
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3080
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3120
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3160
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3200
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3240
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3280
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3320
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3360
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3400
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3440
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3480
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3520
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3560
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3600
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3640
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3680
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3720
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3760
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3800
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3840
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3880
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3920
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-3960
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4000
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4040
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4080
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4120
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4160
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4200
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4240
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4280
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4320
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4360
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4400
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4440
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4480
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4520
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4560
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4600
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4640
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4680
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4720
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4760
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4800
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4840
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4880
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4920
# https://www.opensubtitles.org/en/search/sublanguageid-eng/offset-4960

# %%
import pandas as pd

# %%
tmp = pd.Series(all_url)
tmp.name = "url"

# %%
tmp.to_csv("url.csv", index=False)

# %%
import zipfile
from io import BytesIO
from os.path import exists

from bechdelai.data.scrap import get_data_from_url

def dl_and_save_srt_file(url, save_dir):
    response = get_data_from_url(url)
    f = BytesIO()
    f.write(response.content)
    save_path = "None"

    try:
        with zipfile.ZipFile(f) as zfile:
            for name in zfile.namelist():
                # If not srt file then continue
                if ".srt" not in name:
                    continue
                
                save_path = f"{save_dir}/{name}"
                if exists(save_path):
                    return None
                zfile.extract(name, save_dir)
                break

    except Exception as e:
        return "Error during unzipping:"

    return save_path

# %%
for i, url in enumerate(all_url):
    try:
        res = dl_and_save_srt_file(url, save_dir="data/")
    except Exception as e:
        print("========== ERROR:", e)

    if res is not None:
       print(i, res)
       print(url)
# Out:
# 0 data//better.call.saul.s06e06.720p.web.h264-cakes.Φï▒µûç.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098133
# 1 data//Heart.of.the.Matter.2022.Hallmark.WebripTV.720p.10bit.hevc.Hi.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098130
# 2 data//Heart.of.the.Matter.2022.Hallmark.WebripTV.720p.10bit.hevc.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098128
# 3 data//The.G.Word.with.Adam.Conover.S01E02.Weather.720p.NF.WEB-DL.DDP5.1.x264-SMURF-en-forced.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098106
# 4 data//The.G.Word.with.Adam.Conover.S01E01.Food.720p.NF.WEB-DL.DDP5.1.x264-SMURF-en-forced.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098105
# 5 data//the.staircase.2022.s01e05.720p.web.h264-cakes.Hi.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098103
# 6 data//the.staircase.2022.s01e05.720p.web.h264-cakes.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098102
# 7 data//The.G.Word.with.Adam.Conover.S01E06.Change.720p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098101
# 8 data//The.G.Word.with.Adam.Conover.S01E05.Disease.720p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098100
# 9 data//The.G.Word.with.Adam.Conover.S01E04.Future.720p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098099
# 10 data//The.G.Word.with.Adam.Conover.S01E03.Money.720p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098098
# 11 data//The.G.Word.with.Adam.Conover.S01E02.Weather.720p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098097
# 12 data//The.G.Word.with.Adam.Conover.S01E01.Food.720p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098096
# 13 data//The.G.Word.with.Adam.Conover.S01E06.Change.720p.NF.WEB-DL.DDP5.1.x264-SMURF-HI.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098093
# 14 data//The.G.Word.with.Adam.Conover.S01E05.Disease.720p.NF.WEB-DL.DDP5.1.x264-SMURF-HI.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098092
# 15 data//The.G.Word.with.Adam.Conover.S01E04.Future.720p.NF.WEB-DL.DDP5.1.x264-SMURF-HI.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098091
# 16 data//The.G.Word.with.Adam.Conover.S01E03.Money.720p.NF.WEB-DL.DDP5.1.x264-SMURF-HI.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098090
# 17 data//The.G.Word.with.Adam.Conover.S01E02.Weather.720p.NF.WEB-DL.DDP5.1.x264-SMURF-HI.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098089
# 18 data//The.G.Word.with.Adam.Conover.S01E01.Food.720p.NF.WEB-DL.DDP5.1.x264-SMURF-HI.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098088
# 19 data//The.Photographer.Murder.in.Pinamar.2022.720p.NF.WEB-DL.DUAL.DDP5.1.x264-SMURF-en-forced.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098071
# 20 data//The.Photographer.Murder.in.Pinamar.2022.720p.NF.WEB-DL.DUAL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098070
# 21 data//The.Photographer.Murder.in.Pinamar.2022.720p.NF.WEB-DL.DUAL.DDP5.1.x264-SMURF-HI.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098069
# 22 data//The.Boss.Baby.Back.in.the.Crib.S01E12.1080p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098060
# 23 data//The.Boss.Baby.Back.in.the.Crib.S01E11.1080p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098059
# 24 data//The.Boss.Baby.Back.in.the.Crib.S01E10.1080p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098058
# 25 data//The.Boss.Baby.Back.in.the.Crib.S01E09.1080p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098057
# 26 data//The.Boss.Baby.Back.in.the.Crib.S01E08.1080p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098056
# 27 data//The.Boss.Baby.Back.in.the.Crib.S01E07.1080p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098055
# 28 data//The.Boss.Baby.Back.in.the.Crib.S01E06.1080p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098054
# 29 data//The.Boss.Baby.Back.in.the.Crib.S01E05.1080p.NF.WEB-DL.DDP5.1.x264-SMURF.srt
# https://www.opensubtitles.org/en/subtitleserve/sub/9098053
# 30 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/
Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095973
# 661 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095972
# 662 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095971
# 663 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095970
# 664 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095969
# 665 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095968
# 666 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095967
# 667 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095966
# 668 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095965
# 669 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095963
# 670 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095962
# 671 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095961
# 672 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095960
# 673 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095959
# 674 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095958
# 675 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095957
# 676 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095956
# 677 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095955
# 678 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095954
# 679 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095953
# 680 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095952
# 681 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095951
# 682 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095950
# 683 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095949
# 684 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095948
# 685 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095947
# 686 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095946
# 687 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095945
# 688 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095944
# 689 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095943
# 690 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095942
# 691 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095941
# 692 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095939
# 693 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095938
# 694 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095937
# 695 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095936
# 696 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095935
# 697 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095934
# 698 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095933
# 699 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095932
# 700 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095931
# 701 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095930
# 702 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095929
# 703 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095928
# 704 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095927
# 705 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095926
# 706 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095925
# 707 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095924
# 708 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095923
# 709 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095922
# 710 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095921
# 711 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095920
# 712 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095919
# 713 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095918
# 714 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095916
# 715 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095915
# 716 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095914
# 717 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095913
# 718 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095902
# 719 Error during unzipping:
# https://www.opensubtitles.org/en/subtitleserve/sub/9095871
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1292/2749253452.py in <module>
#       1 for i, url in enumerate(all_url):
#       2     try:
# ----> 3         res = dl_and_save_srt_file(url, save_dir="data/")
#       4     except Exception as e:
#       5         print("========== ERROR:", e)
#
# ~\AppData\Local\Temp/ipykernel_1292/2274651077.py in dl_and_save_srt_file(url, save_dir)
#       6
#       7 def dl_and_save_srt_file(url, save_dir):
# ----> 8     response = get_data_from_url(url)
#       9     f = BytesIO()
#      10     f.write(response.content)
#
# D:\workspace\bechdelai\bechdelai\data\scrap.py in get_data_from_url(url)
#      88
#      89     headers = create_header(url)
# ---> 90     r = requests.get(url, headers=headers)
#      91
#      92     return r
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\Users\natha\apps\miniforge3\envs\bechdelai\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
