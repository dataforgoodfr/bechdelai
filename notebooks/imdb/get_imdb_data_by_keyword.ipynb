# %% [markdown]
# # Get info from a movie

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# In this notebook we want to retrieve movie information such as
# - The name
# - The year
# - Duration
# - Director and producer
# - Casting (ordered by importance)
#
# For the casting, we want the age, gender of the actress / actors

# %% [markdown]
# ## Load packages

# %%
from bechdelai.data.imdb import (
    find_movie_from_kerword,
    show_movie_suggestions_get_id,
    get_movie_data
)
from IPython.display import display, HTML, Markdown
import pandas as pd

# %% [markdown]
# ## Import IMDB Datasets
#
# More details here : https://www.imdb.com/interfaces/

# %%
# %%time
# load big df in scrap file (~2min)
import pandas as pd

name_df = pd.read_csv(
    "../../data/imdb/name.basics.tsv.gz",
    sep="\t",
    usecols=["nconst", "primaryName", "birthYear", "deathYear", "primaryProfession"]
)
basics_df = pd.read_csv(
    "../../data/imdb/title.basics.tsv.gz",
    sep="\t",
    usecols=["tconst", "primaryTitle", "startYear", "runtimeMinutes"],
)
principals_df = pd.read_csv(
    "../../data/imdb/title.principals.tsv.gz",
    sep="\t",
    usecols=["tconst", "ordering", "nconst", "category", "characters"],
)

# crew_df = pd.read_csv("../../data/imdb/title.crew.tsv.gz", sep="\t")
# akas_df = pd.read_csv("../../data/imdb/title.akas.tsv.gz", sep="\t")
# ratings_df = pd.read_csv("../../data/imdb/title.ratings.tsv.gz", sep="\t")
# Out:
# <timed exec>:9: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
# Wall time: 1min 27s

# %% [markdown]
# Preprocess datasets

# %%
# %%time
# Preprocess id into int to be quicker on filters
# TODO : optimize preprocess time
principals_df["tconst"] = principals_df["tconst"].str[2:].astype(int)
principals_df["nconst"] = principals_df["nconst"].str[2:].astype(int)
basics_df["tconst"] = basics_df["tconst"].str[2:].astype(int)
name_df["nconst"] = name_df["nconst"].str[2:].astype(int)
# Out:
# Wall time: 1min 2s

# %% [markdown]
# ## Get list of suggestions from a query (e.g. "Batman")

# %% [markdown]
# ### Get data from keyword

# %%
# %%time
ans = find_movie_from_kerword(q="batman")
# Out:
# Wall time: 4.33 s

# %% [markdown]
# Show posters and select wanted movie

# %%
movie_id, movie_cast_url = show_movie_suggestions_get_id(ans, top=7, verbose=True)
# Out:
# 0 <tr class="findResult odd"> <td class="primary_photo"> <a href="/title/tt1877830/?ref_=fn_tt_tt_1"><img src="https://m.media-amazon.com/images/M/MV5BMDdmMTBiNTYtMDIzNi00NGVlLWIzMDYtZTk3MTQ3NGQxZGEwXkEyXkFqcGdeQXVyMzMwOTU5MDk@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt1877830/?ref_=fn_tt_tt_1">The Batman</a> (2022) </td> </tr>
# 1 <tr class="findResult even"> <td class="primary_photo"> <a href="/title/tt0096895/?ref_=fn_tt_tt_2"><img src="https://m.media-amazon.com/images/M/MV5BMTYwNjAyODIyMF5BMl5BanBnXkFtZTYwNDMwMDk2._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt0096895/?ref_=fn_tt_tt_2">Batman</a> (1989) </td> </tr>
# 2 <tr class="findResult odd"> <td class="primary_photo"> <a href="/title/tt0103359/?ref_=fn_tt_tt_3"><img src="https://m.media-amazon.com/images/M/MV5BOTM3MTRkZjQtYjBkMy00YWE1LTkxOTQtNDQyNGY0YjYzNzAzXkEyXkFqcGdeQXVyOTgwMzk1MTA@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt0103359/?ref_=fn_tt_tt_3">Batman: The Animated Series</a> (1992) (TV Series) </td> </tr>
# 3 <tr class="findResult even"> <td class="primary_photo"> <a href="/title/tt0468569/?ref_=fn_tt_tt_4"><img src="https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt0468569/?ref_=fn_tt_tt_4">The Dark Knight</a> (2008) <br/>aka <i>"Batman - El caballero de la noche"</i> </td> </tr>
# 4 <tr class="findResult odd"> <td class="primary_photo"> <a href="/title/tt0372784/?ref_=fn_tt_tt_5"><img src="https://m.media-amazon.com/images/M/MV5BOTY4YjI2N2MtYmFlMC00ZjcyLTg3YjEtMDQyM2ZjYzQ5YWFkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt0372784/?ref_=fn_tt_tt_5">Batman Begins</a> (2005) </td> </tr>
# 5 <tr class="findResult even"> <td class="primary_photo"> <a href="/title/tt1345836/?ref_=fn_tt_tt_6"><img src="https://m.media-amazon.com/images/M/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt1345836/?ref_=fn_tt_tt_6">The Dark Knight Rises</a> (2012) <br/>aka <i>"Batman: El caballero de la noche asciende"</i> </td> </tr>
# 6 <tr class="findResult odd"> <td class="primary_photo"> <a href="/title/tt0112462/?ref_=fn_tt_tt_7"><img src="https://m.media-amazon.com/images/M/MV5BNDdjYmFiYWEtYzBhZS00YTZkLWFlODgtY2I5MDE0NzZmMDljXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt0112462/?ref_=fn_tt_tt_7">Batman Forever</a> (1995) </td> </tr>
# Select wanted index: 0
# ID of the movie: tt1877830
# URL of the casting: https://www.imdb.com/title/tt1877830/fullcredits

# %% [markdown]
# Get data using `get_movie_data()` function

# %%
# %%time
movie_data = get_movie_data(movie_id, movie_cast_url, name_df, basics_df, principals_df)
# Out:
# Wall time: 4.49 s

# %% [markdown]
# ### Show results

# %%
movie_data.keys()
# Out:
# dict_keys(['tconst', 'primaryTitle', 'startYear', 'runtimeMinutes', 'url', 'director', 'producer', 'cast'])

# %%
pd.DataFrame([movie_data]).iloc[:, :5]
# Out:
#       tconst primaryTitle startYear runtimeMinutes  \
# 0  tt1877830   The Batman      2022            176
#
#                                     url
# 0  https://www.imdb.com/name/tt1877830/

# %%
pd.DataFrame([movie_data["director"]])
# Out:
#       nconst  primaryName birthYear deathYear         primaryProfession  \
# 0  nm0716257  Matt Reeves      1966        \N  producer,writer,director
#
#                                     url gender
# 0  https://www.imdb.com/name/nm0716257/      ?

# %%
pd.DataFrame([movie_data["producer"]])
# Out:
#       nconst  primaryName birthYear deathYear  \
# 0  nm1249995  Dylan Clark        \N        \N
#
#                           primaryProfession  \
# 0  producer,camera_department,miscellaneous
#
#                                     url gender
# 0  https://www.imdb.com/name/nm1249995/      ?

# %%
pd.DataFrame(movie_data["cast"]).head(15)
# Out:
#         nconst         primaryName birthYear deathYear  \
# 0    nm1500155    Robert Pattinson      1986        \N
# 1    nm2368789         Zoë Kravitz      1988        \N
# 2    nm0942482      Jeffrey Wright      1965        \N
# 3    nm0268199       Colin Farrell      1976        \N
# 4    nm0200452           Paul Dano      1984        \N
# 5    nm0001806       John Turturro      1957        \N
# 6    nm0785227         Andy Serkis      1964        \N
# 7    nm0765597     Peter Sarsgaard      1971        \N
# 8    nm4422686       Barry Keoghan      1992        \N
# 9   nm11123883        Jayme Lawson        \N        \N
# 10   nm4909175   Gil Perez-Abraham        \N        \N
# 11   nm0567945      Peter McDonald      1972        \N
# 12   nm0642126         Con O'Neill      1966        \N
# 13   nm0273159          Alex Ferns      1968        \N
# 14   nm0672303  Rupert Penry-Jones      1970        \N
#
#                  primaryProfession                                    url  \
# 0          actor,soundtrack,writer   https://www.imdb.com/name/nm1500155/
# 1      actress,producer,soundtrack   https://www.imdb.com/name/nm2368789/
# 2        actor,producer,soundtrack   https://www.imdb.com/name/nm0942482/
# 3        actor,producer,soundtrack   https://www.imdb.com/name/nm0268199/
# 4        actor,soundtrack,producer   https://www.imdb.com/name/nm0200452/
# 5            actor,writer,director   https://www.imdb.com/name/nm0001806/
# 6          actor,producer,director   https://www.imdb.com/name/nm0785227/
# 7                   actor,producer   https://www.imdb.com/name/nm0765597/
# 8                            actor   https://www.imdb.com/name/nm4422686/
# 9                          actress  https://www.imdb.com/name/nm11123883/
# 10                           actor   https://www.imdb.com/name/nm4909175/
# 11           actor,writer,director   https://www.imdb.com/name/nm0567945/
# 12  actor,soundtrack,miscellaneous   https://www.imdb.com/name/nm0642126/
# 13                  actor,producer   https://www.imdb.com/name/nm0273159/
# 14                           actor   https://www.imdb.com/name/nm0672303/
#
#    gender  ordering
# 0       M         1
# 1       F         2
# 2       M         3
# 3       M         4
# 4       M         5
# 5       M         6
# 6       M         7
# 7       M         8
# 8       M         9
# 9       F        10
# 10      M        11
# 11      M        12
# 12      M        13
# 13      M        14
# 14      M        15

# %% [markdown]
# ### Raw result (as dictionnary)

# %%
movie_data
# Out:
# {'tconst': 'tt1877830',
#  'primaryTitle': 'The Batman',
#  'startYear': '2022',
#  'runtimeMinutes': '176',
#  'url': 'https://www.imdb.com/name/tt1877830/',
#  'director': {'nconst': 'nm0716257',
#   'primaryName': 'Matt Reeves',
#   'birthYear': '1966',
#   'deathYear': '\\N',
#   'primaryProfession': 'producer,writer,director',
#   'url': 'https://www.imdb.com/name/nm0716257/',
#   'gender': '?'},
#  'producer': {'nconst': 'nm1249995',
#   'primaryName': 'Dylan Clark',
#   'birthYear': '\\N',
#   'deathYear': '\\N',
#   'primaryProfession': 'producer,camera_department,miscellaneous',
#   'url': 'https://www.imdb.com/name/nm1249995/',
#   'gender': '?'},
#  'cast': [{'nconst': 'nm1500155',
#    'primaryName': 'Robert Pattinson',
#    'birthYear': '1986',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,soundtrack,writer',
#    'url': 'https://www.imdb.com/name/nm1500155/',
#    'gender': 'M',
#    'ordering': 1},
#   {'nconst': 'nm2368789',
#    'primaryName': 'Zoë Kravitz',
#    'birthYear': '1988',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,producer,soundtrack',
#    'url': 'https://www.imdb.com/name/nm2368789/',
#    'gender': 'F',
#    'ordering': 2},
#   {'nconst': 'nm0942482',
#    'primaryName': 'Jeffrey Wright',
#    'birthYear': '1965',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,producer,soundtrack',
#    'url': 'https://www.imdb.com/name/nm0942482/',
#    'gender': 'M',
#    'ordering': 3},
#   {'nconst': 'nm0268199',
#    'primaryName': 'Colin Farrell',
#    'birthYear': '1976',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,producer,soundtrack',
#    'url': 'https://www.imdb.com/name/nm0268199/',
#    'gender': 'M',
#    'ordering': 4},
#   {'nconst': 'nm0200452',
#    'primaryName': 'Paul Dano',
#    'birthYear': '1984',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,soundtrack,producer',
#    'url': 'https://www.imdb.com/name/nm0200452/',
#    'gender': 'M',
#    'ordering': 5},
#   {'nconst': 'nm0001806',
#    'primaryName': 'John Turturro',
#    'birthYear': '1957',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer,director',
#    'url': 'https://www.imdb.com/name/nm0001806/',
#    'gender': 'M',
#    'ordering': 6},
#   {'nconst': 'nm0785227',
#    'primaryName': 'Andy Serkis',
#    'birthYear': '1964',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,producer,director',
#    'url': 'https://www.imdb.com/name/nm0785227/',
#    'gender': 'M',
#    'ordering': 7},
#   {'nconst': 'nm0765597',
#    'primaryName': 'Peter Sarsgaard',
#    'birthYear': '1971',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,producer',
#    'url': 'https://www.imdb.com/name/nm0765597/',
#    'gender': 'M',
#    'ordering': 8},
#   {'nconst': 'nm4422686',
#    'primaryName': 'Barry Keoghan',
#    'birthYear': '1992',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm4422686/',
#    'gender': 'M',
#    'ordering': 9},
#   {'nconst': 'nm11123883',
#    'primaryName': 'Jayme Lawson',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm11123883/',
#    'gender': 'F',
#    'ordering': 10},
#   {'nconst': 'nm4909175',
#    'primaryName': 'Gil Perez-Abraham',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm4909175/',
#    'gender': 'M',
#    'ordering': 11},
#   {'nconst': 'nm0567945',
#    'primaryName': 'Peter McDonald',
#    'birthYear': '1972',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer,director',
#    'url': 'https://www.imdb.com/name/nm0567945/',
#    'gender': 'M',
#    'ordering': 12},
#   {'nconst': 'nm0642126',
#    'primaryName': "Con O'Neill",
#    'birthYear': '1966',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,soundtrack,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm0642126/',
#    'gender': 'M',
#    'ordering': 13},
#   {'nconst': 'nm0273159',
#    'primaryName': 'Alex Ferns',
#    'birthYear': '1968',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,producer',
#    'url': 'https://www.imdb.com/name/nm0273159/',
#    'gender': 'M',
#    'ordering': 14},
#   {'nconst': 'nm0672303',
#    'primaryName': 'Rupert Penry-Jones',
#    'birthYear': '1970',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm0672303/',
#    'gender': 'M',
#    'ordering': 15},
#   {'nconst': 'nm1017942',
#    'primaryName': 'Kosha Engler',
#    'birthYear': '1977',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm1017942/',
#    'gender': 'F',
#    'ordering': 16},
#   {'nconst': 'nm10706149',
#    'primaryName': 'Archie Barnes',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm10706149/',
#    'gender': 'M',
#    'ordering': 17},
#   {'nconst': 'nm8940462',
#    'primaryName': 'Janine Harouni',
#    'birthYear': '1988',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,writer,producer',
#    'url': 'https://www.imdb.com/name/nm8940462/',
#    'gender': 'F',
#    'ordering': 18},
#   {'nconst': 'nm10460736',
#    'primaryName': 'Hana Hrzic',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm10460736/',
#    'gender': 'F',
#    'ordering': 19},
#   {'nconst': 'nm13450687',
#    'primaryName': 'Joseph Walker',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm13450687/',
#    'gender': 'M',
#    'ordering': 20},
#   {'nconst': 'nm1074361',
#    'primaryName': 'Luke Roberts',
#    'birthYear': '1977',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,miscellaneous,composer',
#    'url': 'https://www.imdb.com/name/nm1074361/',
#    'gender': 'M',
#    'ordering': 21},
#   {'nconst': 'nm10861182',
#    'primaryName': 'Oscar Novak',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': nan,
#    'url': 'https://www.imdb.com/name/nm10861182/',
#    'gender': '?',
#    'ordering': 22},
#   {'nconst': 'nm2706152',
#    'primaryName': 'Stella Stocker',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm2706152/',
#    'gender': 'F',
#    'ordering': 23},
#   {'nconst': 'nm0225549',
#    'primaryName': 'Sandra Dickinson',
#    'birthYear': '1948',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,music_department,soundtrack',
#    'url': 'https://www.imdb.com/name/nm0225549/',
#    'gender': 'F',
#    'ordering': 24},
#   {'nconst': 'nm2108907',
#    'primaryName': 'Jack Bennett',
#    'birthYear': '1980',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer,producer',
#    'url': 'https://www.imdb.com/name/nm2108907/',
#    'gender': 'M',
#    'ordering': 25},
#   {'nconst': 'nm3565933',
#    'primaryName': 'Andre Nightingale',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,camera_department,producer',
#    'url': 'https://www.imdb.com/name/nm3565933/',
#    'gender': 'M',
#    'ordering': 26},
#   {'nconst': 'nm4120348',
#    'primaryName': 'Richard James-Neale',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm4120348/',
#    'gender': 'M',
#    'ordering': 27},
#   {'nconst': 'nm6734796',
#    'primaryName': 'Lorraine Tai',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm6734796/',
#    'gender': 'F',
#    'ordering': 28},
#   {'nconst': 'nm1692732',
#    'primaryName': 'Joseph Balderrama',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm1692732/',
#    'gender': 'M',
#    'ordering': 29},
#   {'nconst': 'nm6823770',
#    'primaryName': 'James Eeles',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm6823770/',
#    'gender': 'M',
#    'ordering': 30},
#   {'nconst': 'nm8242169',
#    'primaryName': 'Angela Yeoh',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm8242169/',
#    'gender': 'F',
#    'ordering': 31},
#   {'nconst': 'nm3760477',
#    'primaryName': 'Leemore Marrett Jr.',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,director',
#    'url': 'https://www.imdb.com/name/nm3760477/',
#    'gender': 'M',
#    'ordering': 32},
#   {'nconst': 'nm11508271',
#    'primaryName': 'Ezra Elliott',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm11508271/',
#    'gender': 'M',
#    'ordering': 33},
#   {'nconst': 'nm5721861',
#    'primaryName': 'Itoya Osagiede',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm5721861/',
#    'gender': 'M',
#    'ordering': 34},
#   {'nconst': 'nm0991334',
#    'primaryName': 'Stewart Alexander',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,producer,director',
#    'url': 'https://www.imdb.com/name/nm0991334/',
#    'gender': 'M',
#    'ordering': 35},
#   {'nconst': 'nm5517140',
#    'primaryName': 'Adam Rojko Vega',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm5517140/',
#    'gender': 'M',
#    'ordering': 36},
#   {'nconst': 'nm4741567',
#    'primaryName': 'Heider Ali',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,sound_department,director',
#    'url': 'https://www.imdb.com/name/nm4741567/',
#    'gender': 'M',
#    'ordering': 37},
#   {'nconst': 'nm3357018',
#    'primaryName': 'Marcus Onilude',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm3357018/',
#    'gender': 'M',
#    'ordering': 38},
#   {'nconst': 'nm3008059',
#    'primaryName': 'Elena Saurel',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,writer,director',
#    'url': 'https://www.imdb.com/name/nm3008059/',
#    'gender': 'F',
#    'ordering': 39},
#   {'nconst': 'nm4591704',
#    'primaryName': 'Ed Kear',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer,producer',
#    'url': 'https://www.imdb.com/name/nm4591704/',
#    'gender': 'M',
#    'ordering': 40},
#   {'nconst': 'nm2874801',
#    'primaryName': 'Sid Sagar',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer',
#    'url': 'https://www.imdb.com/name/nm2874801/',
#    'gender': 'M',
#    'ordering': 41},
#   {'nconst': 'nm11346014',
#    'primaryName': 'Amanda Blake',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm11346014/',
#    'gender': 'F',
#    'ordering': 42},
#   {'nconst': 'nm0101668',
#    'primaryName': 'Todd Boyce',
#    'birthYear': '1961',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm0101668/',
#    'gender': 'M',
#    'ordering': 43},
#   {'nconst': 'nm2200326',
#    'primaryName': 'Brandon Bassir',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm2200326/',
#    'gender': 'M',
#    'ordering': 44},
#   {'nconst': 'nm5993244',
#    'primaryName': 'Will Austin',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,cinematographer,editor',
#    'url': 'https://www.imdb.com/name/nm5993244/',
#    'gender': 'M',
#    'ordering': 45},
#   {'nconst': 'nm5516289',
#    'primaryName': 'Chabris Napier-Lawrence',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm5516289/',
#    'gender': 'F',
#    'ordering': 46},
#   {'nconst': 'nm1245691',
#    'primaryName': 'Douglas Russell',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm1245691/',
#    'gender': 'M',
#    'ordering': 47},
#   {'nconst': 'nm3083350',
#    'primaryName': 'Charlie Carver',
#    'birthYear': '1988',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm3083350/',
#    'gender': 'M',
#    'ordering': 48},
#   {'nconst': 'nm3083571',
#    'primaryName': 'Max Carver',
#    'birthYear': '1988',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer,producer',
#    'url': 'https://www.imdb.com/name/nm3083571/',
#    'gender': 'M',
#    'ordering': 49},
#   {'nconst': 'nm8834313',
#    'primaryName': 'Phil Aizlewood',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm8834313/',
#    'gender': 'M',
#    'ordering': 50},
#   {'nconst': 'nm2075330',
#    'primaryName': 'Mark Killeen',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm2075330/',
#    'gender': 'M',
#    'ordering': 51},
#   {'nconst': 'nm7961549',
#    'primaryName': 'Philip Shaun McGuinness',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm7961549/',
#    'gender': 'M',
#    'ordering': 52},
#   {'nconst': 'nm0114132',
#    'primaryName': 'Lorna Brown',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,soundtrack,executive',
#    'url': 'https://www.imdb.com/name/nm0114132/',
#    'gender': 'F',
#    'ordering': 53},
#   {'nconst': 'nm6544326',
#    'primaryName': 'Elliot Warren',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer,director',
#    'url': 'https://www.imdb.com/name/nm6544326/',
#    'gender': 'M',
#    'ordering': 54},
#   {'nconst': 'nm10649711',
#    'primaryName': 'Jay Lycurgo',
#    'birthYear': '1998',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm10649711/',
#    'gender': 'M',
#    'ordering': 55},
#   {'nconst': 'nm11115099',
#    'primaryName': 'Stefan Race',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': nan,
#    'url': 'https://www.imdb.com/name/nm11115099/',
#    'gender': '?',
#    'ordering': 56},
#   {'nconst': 'nm2959576',
#    'primaryName': 'Elijah Baker',
#    'birthYear': '1991',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer,producer',
#    'url': 'https://www.imdb.com/name/nm2959576/',
#    'gender': 'M',
#    'ordering': 57},
#   {'nconst': 'nm7430613',
#    'primaryName': 'Craige Middleburg',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,assistant_director',
#    'url': 'https://www.imdb.com/name/nm7430613/',
#    'gender': 'M',
#    'ordering': 58},
#   {'nconst': 'nm2009056',
#    'primaryName': 'Akie Kotabe',
#    'birthYear': '1980',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,music_department,camera_department',
#    'url': 'https://www.imdb.com/name/nm2009056/',
#    'gender': 'M',
#    'ordering': 59},
#   {'nconst': 'nm10514458',
#    'primaryName': 'Spike Fearn',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm10514458/',
#    'gender': 'M',
#    'ordering': 60},
#   {'nconst': 'nm11638222',
#    'primaryName': 'Urielle Klein-Mekongo',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm11638222/',
#    'gender': 'F',
#    'ordering': 61},
#   {'nconst': 'nm0916037',
#    'primaryName': 'Bronson Webb',
#    'birthYear': '1983',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm0916037/',
#    'gender': 'M',
#    'ordering': 62},
#   {'nconst': 'nm9254068',
#    'primaryName': 'Madeleine Gray',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm9254068/',
#    'gender': 'F',
#    'ordering': 63},
#   {'nconst': 'nm6964385',
#    'primaryName': 'Ste Johnston',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm6964385/',
#    'gender': 'M',
#    'ordering': 64},
#   {'nconst': 'nm6110544',
#    'primaryName': 'Arthur Lee',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm6110544/',
#    'gender': 'M',
#    'ordering': 65},
#   {'nconst': 'nm6015655',
#    'primaryName': 'Parry Glasspool',
#    'birthYear': '1992',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm6015655/',
#    'gender': 'M',
#    'ordering': 66},
#   {'nconst': 'nm4534452',
#    'primaryName': 'Jordan Coulson',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm4534452/',
#    'gender': 'M',
#    'ordering': 67},
#   {'nconst': 'nm13450688',
#    'primaryName': 'Hadas Gold',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm13450688/',
#    'gender': 'M',
#    'ordering': 68},
#   {'nconst': 'nm4793199',
#    'primaryName': 'Pat Battle',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm4793199/',
#    'gender': 'F',
#    'ordering': 69},
#   {'nconst': 'nm8416667',
#    'primaryName': 'Bobby Cuza',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm8416667/',
#    'gender': 'M',
#    'ordering': 70},
#   {'nconst': 'nm13216937',
#    'primaryName': 'Dean Meminger',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm13216937/',
#    'gender': 'M',
#    'ordering': 71},
#   {'nconst': 'nm0868405',
#    'primaryName': 'Roma Torre',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,producer,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm0868405/',
#    'gender': 'F',
#    'ordering': 72},
#   {'nconst': 'nm8831029',
#    'primaryName': 'Mike Capozzola',
#    'birthYear': '1969',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm8831029/',
#    'gender': 'M',
#    'ordering': 73},
#   {'nconst': 'nm0403787',
#    'primaryName': 'Amanda Hurwitz',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm0403787/',
#    'gender': 'F',
#    'ordering': 74},
#   {'nconst': 'nm12727250',
#    'primaryName': 'Joshua Eldridge-Smith',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm12727250/',
#    'gender': 'M',
#    'ordering': 75},
#   {'nconst': 'nm10340537',
#    'primaryName': 'Daniel Rainford',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm10340537/',
#    'gender': 'M',
#    'ordering': 76},
#   {'nconst': 'nm0035480',
#    'primaryName': 'Nathalie Armin',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm0035480/',
#    'gender': 'F',
#    'ordering': 77},
#   {'nconst': 'nm8462585',
#    'primaryName': 'Jose Palma',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,cinematographer',
#    'url': 'https://www.imdb.com/name/nm8462585/',
#    'gender': 'M',
#    'ordering': 78},
#   {'nconst': 'nm7417369',
#    'primaryName': 'Kazeem Tosin Amore',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm7417369/',
#    'gender': 'M',
#    'ordering': 79},
#   {'nconst': 'nm4364362',
#    'primaryName': 'Rodrig Andrisan',
#    'birthYear': '1958',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,director,writer',
#    'url': 'https://www.imdb.com/name/nm4364362/',
#    'gender': 'M',
#    'ordering': 80},
#   {'nconst': 'nm7722533',
#    'primaryName': 'Eduardo Arrufat-Reboso',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm7722533/',
#    'gender': 'M',
#    'ordering': 81},
#   {'nconst': 'nm5967118',
#    'primaryName': 'Kiran Asahan',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,stunts,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm5967118/',
#    'gender': 'F',
#    'ordering': 82},
#   {'nconst': 'nm2156923',
#    'primaryName': 'Maggie Bakir',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'miscellaneous,actress,director',
#    'url': 'https://www.imdb.com/name/nm2156923/',
#    'gender': 'F',
#    'ordering': 83},
#   {'nconst': 'nm5827547',
#    'primaryName': 'Amy Clare Beales',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,producer,casting_department',
#    'url': 'https://www.imdb.com/name/nm5827547/',
#    'gender': 'F',
#    'ordering': 84},
#   {'nconst': 'nm7586734',
#    'primaryName': 'Douglas Bunn',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,art_department,stunts',
#    'url': 'https://www.imdb.com/name/nm7586734/',
#    'gender': 'M',
#    'ordering': 85},
#   {'nconst': 'nm9916443',
#    'primaryName': 'Ruth Clarson-Horrocks',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,miscellaneous,casting_department',
#    'url': 'https://www.imdb.com/name/nm9916443/',
#    'gender': 'F',
#    'ordering': 86},
#   {'nconst': 'nm0171625',
#    'primaryName': 'Bern Collaço',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm0171625/',
#    'gender': 'M',
#    'ordering': 87},
#   {'nconst': 'nm7204833',
#    'primaryName': 'Andreea Helen David',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,producer,director',
#    'url': 'https://www.imdb.com/name/nm7204833/',
#    'gender': 'F',
#    'ordering': 88},
#   {'nconst': 'nm7618414',
#    'primaryName': 'Nick Davison',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm7618414/',
#    'gender': 'M',
#    'ordering': 89},
#   {'nconst': 'nm5940174',
#    'primaryName': 'Craig Douglas',
#    'birthYear': '1986',
#    'deathYear': '\\N',
#    'primaryProfession': 'writer,director,actor',
#    'url': 'https://www.imdb.com/name/nm5940174/',
#    'gender': 'M',
#    'ordering': 90},
#   {'nconst': 'nm9728295',
#    'primaryName': 'Evan A. Dunn',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm9728295/',
#    'gender': 'M',
#    'ordering': 91},
#   {'nconst': 'nm7303783',
#    'primaryName': 'Daniel Eghan',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,sound_department,director',
#    'url': 'https://www.imdb.com/name/nm7303783/',
#    'gender': 'M',
#    'ordering': 92},
#   {'nconst': 'nm12114683',
#    'primaryName': 'Hayden Ellingworth',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm12114683/',
#    'gender': 'M',
#    'ordering': 93},
#   {'nconst': 'nm11200051',
#    'primaryName': 'Darcie Ellson',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,cinematographer,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm11200051/',
#    'gender': 'F',
#    'ordering': 94},
#   {'nconst': 'nm11797631',
#    'primaryName': 'Joseph L Geist',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer',
#    'url': 'https://www.imdb.com/name/nm11797631/',
#    'gender': 'M',
#    'ordering': 95},
#   {'nconst': 'nm6897938',
#    'primaryName': 'Albert Giannitelli',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,producer,writer',
#    'url': 'https://www.imdb.com/name/nm6897938/',
#    'gender': 'M',
#    'ordering': 96},
#   {'nconst': 'nm5938446',
#    'primaryName': 'Susan Gillias',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm5938446/',
#    'gender': 'F',
#    'ordering': 97},
#   {'nconst': 'nm5515625',
#    'primaryName': 'George Graham',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'camera_department,director,assistant_director',
#    'url': 'https://www.imdb.com/name/nm5515625/',
#    'gender': '?',
#    'ordering': 98},
#   {'nconst': 'nm5564735',
#    'primaryName': 'Rachel Handshaw',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,writer',
#    'url': 'https://www.imdb.com/name/nm5564735/',
#    'gender': 'F',
#    'ordering': 99},
#   {'nconst': 'nm8645371',
#    'primaryName': 'Juke Hardy',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm8645371/',
#    'gender': 'M',
#    'ordering': 100},
#   {'nconst': 'nm9112737',
#    'primaryName': 'Metin Hassan',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm9112737/',
#    'gender': 'M',
#    'ordering': 101},
#   {'nconst': 'nm5354437',
#    'primaryName': 'Simon Jago',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'visual_effects,actor,director',
#    'url': 'https://www.imdb.com/name/nm5354437/',
#    'gender': 'M',
#    'ordering': 102},
#   {'nconst': 'nm4118987',
#    'primaryName': 'Yasmin J. James',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm4118987/',
#    'gender': 'F',
#    'ordering': 103},
#   {'nconst': 'nm6556096',
#    'primaryName': 'Tobias James-Samuels',
#    'birthYear': '1977',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm6556096/',
#    'gender': 'M',
#    'ordering': 104},
#   {'nconst': 'nm8958189',
#    'primaryName': 'Adnan Kundi',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm8958189/',
#    'gender': 'M',
#    'ordering': 105},
#   {'nconst': 'nm3434365',
#    'primaryName': 'Erran Lake',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'visual_effects,art_department,actor',
#    'url': 'https://www.imdb.com/name/nm3434365/',
#    'gender': 'M',
#    'ordering': 106},
#   {'nconst': 'nm6118829',
#    'primaryName': 'Mickey Lewis',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm6118829/',
#    'gender': 'M',
#    'ordering': 107},
#   {'nconst': 'nm4589715',
#    'primaryName': 'Annishia Camilla Lunette',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm4589715/',
#    'gender': 'F',
#    'ordering': 108},
#   {'nconst': 'nm2972606',
#    'primaryName': 'Teresa Mahoney',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,miscellaneous,stunts',
#    'url': 'https://www.imdb.com/name/nm2972606/',
#    'gender': 'F',
#    'ordering': 109},
#   {'nconst': 'nm6515672',
#    'primaryName': 'Tiago Martins',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm6515672/',
#    'gender': 'M',
#    'ordering': 110},
#   {'nconst': 'nm1975399',
#    'primaryName': 'Obie Matthew',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,miscellaneous,stunts',
#    'url': 'https://www.imdb.com/name/nm1975399/',
#    'gender': 'M',
#    'ordering': 111},
#   {'nconst': 'nm5683938',
#    'primaryName': 'Nichola Jean Mazur',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress,writer',
#    'url': 'https://www.imdb.com/name/nm5683938/',
#    'gender': 'F',
#    'ordering': 112},
#   {'nconst': 'nm8728573',
#    'primaryName': 'Kenny-Lee Mbanefo',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm8728573/',
#    'gender': 'M',
#    'ordering': 113},
#   {'nconst': 'nm11105476',
#    'primaryName': 'Tony McCarthy',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm11105476/',
#    'gender': 'M',
#    'ordering': 114},
#   {'nconst': 'nm5126775',
#    'primaryName': 'Bharat Mistri',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,camera_department,executive',
#    'url': 'https://www.imdb.com/name/nm5126775/',
#    'gender': 'M',
#    'ordering': 115},
#   {'nconst': 'nm10299282',
#    'primaryName': 'Sri Moorthy',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm10299282/',
#    'gender': 'M',
#    'ordering': 116},
#   {'nconst': 'nm4016944',
#    'primaryName': 'Nick Owenford',
#    'birthYear': '1968',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm4016944/',
#    'gender': 'M',
#    'ordering': 117},
#   {'nconst': 'nm11658882',
#    'primaryName': 'Zoltan Rencsar',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm11658882/',
#    'gender': 'M',
#    'ordering': 118},
#   {'nconst': 'nm9309101',
#    'primaryName': 'Paul Riddell',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,producer',
#    'url': 'https://www.imdb.com/name/nm9309101/',
#    'gender': 'M',
#    'ordering': 119},
#   {'nconst': 'nm9555373',
#    'primaryName': 'Will Rowlands',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,producer,writer',
#    'url': 'https://www.imdb.com/name/nm9555373/',
#    'gender': 'M',
#    'ordering': 120},
#   {'nconst': 'nm12087065',
#    'primaryName': 'Iana Saliuk',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actress',
#    'url': 'https://www.imdb.com/name/nm12087065/',
#    'gender': 'F',
#    'ordering': 121},
#   {'nconst': 'nm7441016',
#    'primaryName': 'Bernardo Santos',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm7441016/',
#    'gender': 'M',
#    'ordering': 122},
#   {'nconst': 'nm10194407',
#    'primaryName': 'Eugene Shawn',
#    'birthYear': '1993',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm10194407/',
#    'gender': 'M',
#    'ordering': 123},
#   {'nconst': 'nm6078944',
#    'primaryName': 'Dave Simon',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,producer',
#    'url': 'https://www.imdb.com/name/nm6078944/',
#    'gender': 'M',
#    'ordering': 124},
#   {'nconst': 'nm3046500',
#    'primaryName': 'Jimmy Star',
#    'birthYear': '1964',
#    'deathYear': '\\N',
#    'primaryProfession': 'producer,miscellaneous,actor',
#    'url': 'https://www.imdb.com/name/nm3046500/',
#    'gender': 'M',
#    'ordering': 125},
#   {'nconst': 'nm9378323',
#    'primaryName': 'Alfredo Tavares',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,animation_department',
#    'url': 'https://www.imdb.com/name/nm9378323/',
#    'gender': 'M',
#    'ordering': 126},
#   {'nconst': 'nm4880315',
#    'primaryName': 'Vic Waghorn',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,assistant_director,casting_department',
#    'url': 'https://www.imdb.com/name/nm4880315/',
#    'gender': 'M',
#    'ordering': 127},
#   {'nconst': 'nm8004657',
#    'primaryName': 'Stuart Whelan',
#    'birthYear': '1965',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,miscellaneous',
#    'url': 'https://www.imdb.com/name/nm8004657/',
#    'gender': 'M',
#    'ordering': 128},
#   {'nconst': 'nm5131834',
#    'primaryName': 'Paul Whelligan',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm5131834/',
#    'gender': 'M',
#    'ordering': 129},
#   {'nconst': 'nm11646175',
#    'primaryName': 'Chosen Wilkins',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor,writer',
#    'url': 'https://www.imdb.com/name/nm11646175/',
#    'gender': 'M',
#    'ordering': 130},
#   {'nconst': 'nm9281009',
#    'primaryName': 'Daniel Joseph Woolf',
#    'birthYear': '\\N',
#    'deathYear': '\\N',
#    'primaryProfession': 'actor',
#    'url': 'https://www.imdb.com/name/nm9281009/',
#    'gender': 'M',
#    'ordering': 131}]}
