# %%
import requests

# %%
url = 'https://bechdeltest.com/api/v1/getMoviesByTitle?title=matrix'
url = 'http://bechdeltest.com/api/v1/getAllMovies'
#url = "https://www.allocine.fr/film/fichefilm_gen_cfilm=211012.html"

# %%
r=requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '[{"imdbid":"3155794","title":"Passage de Venus","id":9602,"year":1874,"rating":0},{"imdbid":"14495706","id":9804,"year":1877,"rating":0,"title":"La Rosace Magique"},{"year":1878,"rating":0,"id":9603,"title":"Sallie Gardner at a Gallop","imdbid":"2221420"},{"rating":0,"year":1878,"id":9806,"title":"Le singe musicien","imdbid":"12592084"},{"year":1881,"id":9816,"rating":0,"title":"Athlete Swinging a Pick","imdbid":"7816420"},{"title":"Buffalo Running","year":1883,"id":9831,"rating":0,"imdbid":"5459794"},{"rating":0,"year":1885,"id":9832,"title":"L&#39;homme machine","imdbid":"8588366"},{"title":"Man Walking Around the Corner","rating":0,"year":1887,"id":9614,"imdbid":"2075247"},{"title":"Cockatoo Flying","rating":0,"year":1887,"id":9836,"imdbid":"8133192"},{"imdbid":"7411790","rating":0,"year":1887,"id":9837,"title":"Child Carrying Flowers to Woman"},{"rating":0,"year":1887,"id":9838,"title":"Jumping Over a Man&#39;s Back-Leapfrog","imdbid":"7541160"},{"title":"Man Riding Jumping Hors
# ...

# %%
data=pd.DataFrame(r.json())

# %%
import pandas as pd

# %%
data.to_excel('All.xlsx')

# %%
data
# Out:
#         imdbid                       title     id  year  rating
# 0      3155794            Passage de Venus   9602  1874       0
# 1     14495706           La Rosace Magique   9804  1877       0
# 2      2221420  Sallie Gardner at a Gallop   9603  1878       0
# 3     12592084           Le singe musicien   9806  1878       0
# 4      7816420     Athlete Swinging a Pick   9816  1881       0
# ...        ...                         ...    ...   ...     ...
# 9412   4995540          Being The Ricardos  10199  2021       3
# 9413  11127680               Boiling Point  10200  2021       3
# 9414  10293406       Power of the Dog, The  10202  2021       0
# 9415  11389748                        Mass  10206  2021       3
# 9416   8356942                    355, The  10195  2022       3
#
# [9417 rows x 5 columns]

# %%
data.to_excel('All_movies.xlsx')

# %%
from bechdelai.data.allocine import get_movies
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-a1f4e28123fc> in <module>
# ----> 1 from bechdelai.data.allocine import get_movies
#
# ModuleNotFoundError: No module named 'bechdelai'
