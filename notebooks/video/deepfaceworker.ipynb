# %%
import sys
import shutil
import time
sys.path.append('/home/virgaux/dataforgood/bechdelai/bechdelai')
import processing.extract_img
import processing.load_data
import data.youtube
# Out:
# 2022-07-26 19:24:18.882942: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/virgaux/dataforgood/bechdelai/venv/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-07-26 19:24:18.882963: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
extractor = data.youtube.Extract_Video_YT("https://www.youtube.com/watch?v=N3bGygszW5s&list=RDMMLfuNPS4qAVY&index=10")
extractor.download_video()
# Out:
#  ↳ |████████████████████████████████████████████| 100.0%

# %%
extractor = processing.extract_img.Extract_One_Video("/home/virgaux/dataforgood/bechdelai/data/sample_video_yt/Leïla Huissoud - La Niaise [Clip Officiel].mp4")
extractor.extract_info_from_videos(detail="/home/virgaux/dataforgood/bechdelai/data/sample_video_yt/Leïla Huissoud - La Niaise [Clip Officiel].json")
# Out:
# 0.000%|          | 0/5202 [00:00<?2022-07-26 19:24:22.233718: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-26 19:24:22.233747: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (virgaux-All-Series): /proc/driver/nvidia/version does not exist
# 2022-07-26 19:24:22.234093: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 100.000%|██████████| 5202/5202 [00:02<00:00

# %%
loader = processing.load_data.LoaderData("/home/virgaux/dataforgood/bechdelai/data/sample_video_yt/Leïla Huissoud - La Niaise [Clip Officiel]")
dataset = loader.load_dataset()

# %%
disp = processing.load_data.Displayer(dataset)
disp.show_img(num_batch=2)
